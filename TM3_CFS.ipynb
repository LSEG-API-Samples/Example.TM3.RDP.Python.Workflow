# %% [markdown]
# # TM3 CFS File Workflow
#
# **Last Updated**: Aug 2025
#
# Example Code Disclaimer:
# ALL EXAMPLE CODE IS PROVIDED ON AN “AS IS” AND “AS AVAILABLE” BASIS FOR ILLUSTRATIVE PURPOSES ONLY. LSEG MAKES NO REPRESENTATIONS OR WARRANTIES OF ANY KIND, EXPRESS OR IMPLIED, AS TO THE OPERATION OF THE EXAMPLE CODE, OR THE INFORMATION, CONTENT, OR MATERIALS USED IN CONNECTION WITH THE EXAMPLE CODE. YOU EXPRESSLY AGREE THAT YOUR USE OF THE EXAMPLE CODE IS AT YOUR SOLE RISK.

# %% [markdown]
# ### Importing libararies

# %%
import os
import sys
import requests 
import json
from dotenv import dotenv_values
config = dotenv_values('.env')

# %% [markdown]
# ### Set RDP credentials and Initial Parameters

# %%
username = config['MACHINE_ID'] #Or replace with your RDP Machine-ID
password = config['PASSWORD'] #Or replace with your RDP Password
clientId = config['APP_KEY'] #Or replace with your RDP APP Key

RDP_HOST= 'https://api.refinitiv.com'
acccess_token = None
refresh_token = None
expires_in = 0

# %% [markdown]
# ### Step 1: Authentication with RDP APIs
#
# RDP APIs entitlement check is based on OAuth 2.0 specification. The first step of an application workflow is to get a token from RDP Auth Service, which will allow access to the protected resource, i.e. data REST API.
#
# The API requires the following access credential information:
# - Username: The username.
# - Password: Password associated with the username.
# - Client ID: This is also known as ```AppKey```, and it is generated using an App key Generator. This unique identifier is defined for the user or application and is deemed confidential (not shared between users). The client_id parameter can be passed in the request body or as an “Authorization” request header that is encoded as base64.
# - Grant Type ```password```: This is for initial authentication request. An application does not have any token, so it requests new tokens using username/password combination.
#
# ``` HTTP
# POST /auth/oauth2/v1/token HTTP/1.1
# Accept: */*
# Content-Type: application/x-www-form-urlencoded
# Host: api.refinitiv.com:443
# Content-Length: XXX
#
# username=RDP_USERNAME
# &password=RDP_PASSWORD
# &client_id=RDP_APP_KEY
# &grant_type=password
# &takeExclusiveSignOnControl=true
# &scope=trapi
# ```

# %%
#step 1 - get RDP Access Token from RDP

# Send HTTP Request
auth_url = f'{RDP_HOST}/auth/oauth2/v1/token'
payload = f'grant_type=password&username={username}&client_id={clientId}&password={password}&takeExclusiveSignOnControl=True&scope=trapi'
try:
    auth_response = requests.post(auth_url, 
                             headers = {'Content-Type':'application/x-www-form-urlencoded'}, 
                             data = payload, 
                             auth = (clientId, '')
                )
except requests.exceptions.RequestException as exp:
    print(f'Caught exception: {exp}')

if auth_response.status_code == 200:  # HTTP Status 'OK'
    print('Authentication success')
    access_token = auth_response.json()['access_token']
    refresh_token = auth_response.json()['refresh_token']
    expires_in = int(auth_response.json()['expires_in'])

if auth_response.status_code != 200:
    print(f'RDP authentication failure: {auth_response.status_code} {auth_response.reason}')
    print(f'Text: {auth_response.text}')
# Out:
# Authentication success

# %% [markdown]
# Once the authentication success, the function gets the RDP Auth service response message and keeps the following RDP token information in the variables.
# - **access_token**: The token used to invoke REST data API calls as described above. The application must keep this credential for further RDP APIs requests.
# - **refresh_token**: Refresh token to be used for obtaining an updated access token before expiration. The application must keep this credential for access token renewal.
# - **expires_in**: Access token validity time in seconds.
#
# After the application received the Access Token (and authorization token) from RDP Auth Service, all subsequent REST API calls will use this token to get the data via the *Authorization* HTTP request message header as shown below.
# - Header:
#     * Authorization = ```Bearer <RDP Access Token>```
#
# Please notice *the space* between the ```Bearer``` and ```RDP Access Token``` values.

# %% [markdown]
# ### Step 2: Query for specific Date using modifiedSince and pageSize=100 to limit data return<-- Recommended One
#
# Now we come to getting the ```FileSets``` information.  The ```modifiedSince``` parameter can help an application to limit the returned File-Set only for the File-Set that has been modified after a specified time.
#
# The application needs to send an HTTP ```GET``` request to the RDP ```/file-store/v1/file-sets?bucket=buck-Custom&packageId={packageId}&pageSize=100``` endpoint to list **the first** 100 FileSets under the input ```bucket-name``` and ```packageId``` that has been modified since ```modifiedSince``` as follows.
#
# ``` HTTP
# GET /file-store/v1/file-sets?bucket={bucket-name}&packageId={packageId}&modifiedSince={datetime}&pageSize=100 HTTP/1.1
# Host: api.refinitiv.com
# Authorization: Bearer <Access Token>
# ```
#
# Example:
#
# ``` HTTP
# GET /file-store/v1/file-sets?bucket=bulk-ESG&packageId=4288-ebb6-93372235-acb2-89882a826af1&pageSize=100&modifiedSince=2022-01-26T00:00:00Z HTTP/1.1
# Host: api.refinitiv.com
# Authorization: Bearer <Access Token>
# ```
#
# The ```bucket-name``` for the TM3 (Municipal Market Monitor) feed data is **bulk-Custom**.
#
# Please contact your LSEG representative to help you with the ```packageId```.

# %%
# pick the packageId you need and set to the packageId variable
#packageId = response.json()['value'][0]['packageId']
packageId = config['PACKAGE_ID']
bucket_name = 'bulk-Custom'

# %%
#step 2 - list FileSets from bucket name and package Id and modifiedSince

CFS_url = f'{RDP_HOST}/file-store/v1/file-sets'

params = {
    'bucket': bucket_name,
    'packageId': packageId,
    'pageSize': 100,
    'modifiedSince':'2025-07-25T12:00:00Z'
}

try:
    fileSet_response = requests.get(CFS_url, params=params, headers={'Authorization': f'Bearer {access_token}'})
except requests.exceptions.RequestException as exp:
    print(f'Caught exception: {exp}')

if fileSet_response.status_code == 200:  # HTTP Status 'OK'
    print('Receive FileSets list from RDP APIs')
else:
    print(f'RDP APIs: CFS request failure: {fileSet_response.status_code} {fileSet_response.reason}')
    print(f'Text: {fileSet_response.text}')
# Out:
# Receive FileSets list from RDP APIs

# %% [markdown]
# Example of FileSets

# %%
print(json.dumps(fileSet_response.json()['value'], sort_keys=True, indent=2, separators=(',', ':')))
# Out:
# [
#   {
#     "attributes":[],
#     "availableFrom":"2025-07-29T20:56:38Z",
#     "availableTo":"2026-01-29T20:56:37Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-07-29T20:50:00Z",
#     "contentTo":"2025-07-29T20:55:00Z",
#     "created":"2025-07-29T20:56:38Z",
#     "files":[
#       "4b7d-cd53-0631a812-9207-95b66f8fc5ca"
#     ],
#     "id":"4af1-0efc-df11c8a3-b0ce-6d0a70b6f0e9",
#     "modified":"2025-07-29T20:56:41Z",
#     "name":"TM3_SIFMAIndex2025-07-29",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-07-30T20:56:33Z",
#     "availableTo":"2026-01-30T20:56:33Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-07-30T20:50:00Z",
#     "contentTo":"2025-07-30T20:55:00Z",
#     "created":"2025-07-30T20:56:33Z",
#     "files":[
#       "4eda-d4b4-34cf5dab-a6d9-e9a8ed3031fa"
#     ],
#     "id":"4460-b76d-fac7ad8c-ba51-020f300f8bf7",
#     "modified":"2025-07-30T20:56:36Z",
#     "name":"TM3_SIFMAIndex2025-07-30",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-07-31T20:56:14Z",
#     "availableTo":"2026-01-31T20:56:13Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-07-31T20:50:00Z",
#     "contentTo":"2025-07-31T20:55:00Z",
#     "created":"2025-07-31T20:56:14Z",
#     "files":[
#       "4e6a-aad8-032daa50-8f36-1a0c1af4943c"
#     ],
#     "id":"4a41-3199-7401bee9-93a6-98414cb72b5c",
#     "modified":"2025-07-31T20:56:16Z",
#     "name":"TM3_SIFMAIndex2025-07-31",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-08-05T20:56:18Z",
#     "availableTo":"2026-02-05T20:56:17Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-08-05T20:50:00Z",
#     "contentTo":"2025-08-05T20:55:00Z",
#     "created":"2025-08-05T20:56:18Z",
#     "files":[
#       "4ec8-010a-3379a1f2-86d9-14631e49e74b"
#     ],
#     "id":"4cf8-0b9d-e47fec9d-815e-617500a3ed36",
#     "modified":"2025-08-05T20:56:21Z",
#     "name":"TM3_SIFMAIndex2025-08-05",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-08-06T20:56:09Z",
#     "availableTo":"2026-02-06T20:56:08Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-08-06T20:50:00Z",
#     "contentTo":"2025-08-06T20:55:00Z",
#     "created":"2025-08-06T20:56:09Z",
#     "files":[
#       "4229-c5f0-6231c0e5-8499-62fe598d63ae"
#     ],
#     "id":"4330-85b2-cf675f1f-90e2-2650ee959341",
#     "modified":"2025-08-06T20:56:11Z",
#     "name":"TM3_SIFMAIndex2025-08-06",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-08-07T20:56:07Z",
#     "availableTo":"2026-02-07T20:56:06Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-08-07T20:50:00Z",
#     "contentTo":"2025-08-07T20:55:00Z",
#     "created":"2025-08-07T20:56:07Z",
#     "files":[
#       "4892-55ea-56b0a98a-ac80-c24d16ac34f0"
#     ],
#     "id":"4b20-1b16-c921a7b1-b824-6443c8f3727a",
#     "modified":"2025-08-07T20:56:10Z",
#     "name":"TM3_SIFMAIndex2025-08-07",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-08-12T20:56:21Z",
#     "availableTo":"2026-02-12T20:56:20Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-08-12T20:50:00Z",
#     "contentTo":"2025-08-12T20:55:00Z",
#     "created":"2025-08-12T20:56:21Z",
#     "files":[
#       "45b7-c5b9-dc845e53-82d9-2313307fb8c6"
#     ],
#     "id":"470e-2420-357307ff-98da-2b1da226939f",
#     "modified":"2025-08-12T20:56:24Z",
#     "name":"TM3_SIFMAIndex2025-08-12",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-08-13T20:56:28Z",
#     "availableTo":"2026-02-13T20:56:27Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-08-13T20:50:00Z",
#     "contentTo":"2025-08-13T20:55:00Z",
#     "created":"2025-08-13T20:56:28Z",
#     "files":[
#       "42ae-f644-4f7439b3-ae19-224d6af53e17"
#     ],
#     "id":"486e-565f-70e9e3f9-95ad-15cd2b8a1c3a",
#     "modified":"2025-08-13T20:56:31Z",
#     "name":"TM3_SIFMAIndex2025-08-13",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-08-14T20:56:37Z",
#     "availableTo":"2026-02-14T20:56:36Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-08-14T20:50:00Z",
#     "contentTo":"2025-08-14T20:55:00Z",
#     "created":"2025-08-14T20:56:37Z",
#     "files":[
#       "48f2-be28-92dc9f53-902a-443f158e8ec3"
#     ],
#     "id":"45da-9433-6ba54a84-bb19-17945dc6ce0c",
#     "modified":"2025-08-14T20:56:40Z",
#     "name":"TM3_SIFMAIndex2025-08-14",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-08-19T20:56:40Z",
#     "availableTo":"2026-02-19T20:56:38Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-08-19T20:50:00Z",
#     "contentTo":"2025-08-19T20:55:00Z",
#     "created":"2025-08-19T20:56:40Z",
#     "files":[
#       "4121-60d3-4fafa863-8020-8576e39e0fab"
#     ],
#     "id":"4bef-ed22-ba7a742d-af79-3ed60627e5ec",
#     "modified":"2025-08-19T20:56:42Z",
#     "name":"TM3_SIFMAIndex2025-08-19",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-08-20T20:56:05Z",
#     "availableTo":"2026-02-20T20:56:04Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-08-20T20:50:00Z",
#     "contentTo":"2025-08-20T20:55:00Z",
#     "created":"2025-08-20T20:56:05Z",
#     "files":[
#       "4447-af76-c1718e05-aff6-6d5341a1eac6"
#     ],
#     "id":"4482-3c5e-225a3824-bb27-8ff35b9e66b3",
#     "modified":"2025-08-20T20:56:08Z",
#     "name":"TM3_SIFMAIndex2025-08-20",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   }
# ]

# %% [markdown]
# The File ID is in the **files** array. Select the one that you need.
#
# I am demonstrating with the first entry.

# %%
# try just one file
file_id = fileSet_response.json()['value'][0]['files'][0]
print(file_id)
# Out:
# 4b7d-cd53-0631a812-9207-95b66f8fc5ca

# %% [markdown]
# ### Step 2.5: Or you can listing the 100 records of the FileSets using the Bucket Name and Package ID and pageSize=100
#
# ``` HTTP
# GET /file-store/v1/file-sets?bucket={bucket-name}&packageId={packageId}&pageSize=100 HTTP/1.1
# Host: api.refinitiv.com
# Authorization: Bearer <Access Token>
# ```

# %%
#step 2.5 - list FileSets from bucket name and package Id

CFS_url = f'{RDP_HOST}/file-store/v1/file-sets'

fileSet_response = None

params = {
    'bucket': bucket_name,
    'packageId': packageId,
    'pageSize': 100
}

try:
    fileSet_response = requests.get(CFS_url, params=params, headers={'Authorization': f'Bearer {access_token}'})
except requests.exceptions.RequestException as exp:
    print(f'Caught exception: {exp}')

if fileSet_response.status_code == 200:  # HTTP Status 'OK'
    print('Receive FileSets list from RDP APIs')
else:
    print(f'RDP APIs: CFS request failure: {fileSet_response.status_code} {fileSet_response.reason}')
    print(f'Text: {fileSet_response.text}')
# Out:
# Receive FileSets list from RDP APIs

# %% [markdown]
# Example of theFileSets.

# %%
print(json.dumps(fileSet_response.json()['value'], sort_keys=True, indent=2, separators=(',', ':')))
# Out:
# [
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-10T18:35:58Z",
#     "availableTo":"2025-12-10T18:35:58Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-10T18:30:00Z",
#     "contentTo":"2025-06-10T18:35:00Z",
#     "created":"2025-06-10T18:35:58Z",
#     "files":[
#       "456c-388a-1e9b601a-afff-03fb592bcd20"
#     ],
#     "id":"4006-9157-7a0fc5e1-862e-950478c22a4e",
#     "modified":"2025-06-10T18:36:01Z",
#     "name":"TM3_SIFMAIndex2025-06-10T14:35:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-06T17:27:36Z",
#     "availableTo":"2025-11-06T17:27:36Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-06T17:20:00Z",
#     "contentTo":"2025-05-06T17:25:00Z",
#     "created":"2025-05-06T17:27:36Z",
#     "files":[
#       "4ce5-f175-af239ab4-901e-980e8421fa5b"
#     ],
#     "id":"400a-5326-23b3c2bf-87ab-e944e06ac777",
#     "modified":"2025-05-06T17:27:39Z",
#     "name":"TM3_SIFMAIndex2025-05-06T13:25:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-22T18:11:27Z",
#     "availableTo":"2025-11-22T18:11:27Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-22T18:05:00Z",
#     "contentTo":"2025-05-22T18:10:00Z",
#     "created":"2025-05-22T18:11:27Z",
#     "files":[
#       "43d7-c6a9-5606cc46-aadb-3a2956aee17e"
#     ],
#     "id":"400a-b124-8d5b285c-b8e7-196c8cb6b363",
#     "modified":"2025-05-22T18:11:30Z",
#     "name":"TM3_SIFMAIndex2025-05-22T14:10:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-06T20:42:00Z",
#     "availableTo":"2025-11-06T20:41:59Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-06T20:35:00Z",
#     "contentTo":"2025-05-06T20:40:00Z",
#     "created":"2025-05-06T20:42:00Z",
#     "files":[
#       "4122-202a-76877d41-a207-294439244348"
#     ],
#     "id":"4011-3ee5-761d8137-b58b-ae98c9f1e96b",
#     "modified":"2025-05-06T20:42:02Z",
#     "name":"TM3_SIFMAIndex2025-05-06T16:40:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-10T20:06:16Z",
#     "availableTo":"2025-12-10T20:06:16Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-10T20:00:00Z",
#     "contentTo":"2025-06-10T20:05:00Z",
#     "created":"2025-06-10T20:06:16Z",
#     "files":[
#       "481e-01d3-ab6b0052-af23-98bbef9e5f1d"
#     ],
#     "id":"4011-95bc-815fe9b1-bbcd-e3459880c841",
#     "modified":"2025-06-10T20:06:19Z",
#     "name":"TM3_SIFMAIndex2025-06-10T16:05:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-08T20:36:40Z",
#     "availableTo":"2025-11-08T20:36:40Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-08T20:30:00Z",
#     "contentTo":"2025-05-08T20:35:00Z",
#     "created":"2025-05-08T20:36:40Z",
#     "files":[
#       "4851-ee3f-9c9df3e7-9ccd-25e1a2cbaaab"
#     ],
#     "id":"4017-200c-168b6ba6-9fd3-b8d48c011290",
#     "modified":"2025-05-08T20:36:43Z",
#     "name":"TM3_SIFMAIndex2025-05-08T16:35:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-07T18:47:45Z",
#     "availableTo":"2025-11-07T18:47:44Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-07T18:40:00Z",
#     "contentTo":"2025-05-07T18:45:00Z",
#     "created":"2025-05-07T18:47:45Z",
#     "files":[
#       "47b3-1528-73db5e0e-b85d-d427f14fa57b"
#     ],
#     "id":"4018-c292-0f55d597-a045-cfb22a372bb9",
#     "modified":"2025-05-07T18:47:47Z",
#     "name":"TM3_SIFMAIndex2025-05-07T14:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-29T16:26:18Z",
#     "availableTo":"2025-11-29T16:26:18Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-29T16:20:00Z",
#     "contentTo":"2025-05-29T16:25:00Z",
#     "created":"2025-05-29T16:26:18Z",
#     "files":[
#       "4ecd-8761-93c034b0-9d85-c25afb288017"
#     ],
#     "id":"401e-dc4b-7f4f14f2-9154-db2d57fe0ef2",
#     "modified":"2025-05-29T16:26:21Z",
#     "name":"TM3_SIFMAIndex2025-05-29T12:25:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-17T18:06:24Z",
#     "availableTo":"2025-10-17T18:06:24Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-17T18:00:00Z",
#     "contentTo":"2025-04-17T18:05:00Z",
#     "created":"2025-04-17T18:06:24Z",
#     "files":[
#       "4768-ccb6-a94594f6-82a1-4500a17b2bd5"
#     ],
#     "id":"401e-eca9-99e42ee6-be5b-0d5a80db704f",
#     "modified":"2025-04-17T18:06:25Z",
#     "name":"TM3_SIFMAIndex2025-04-17T14:05:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-06T20:06:36Z",
#     "availableTo":"2025-11-06T20:06:36Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-06T20:00:00Z",
#     "contentTo":"2025-05-06T20:05:00Z",
#     "created":"2025-05-06T20:06:36Z",
#     "files":[
#       "41bd-f811-a8e98d77-a222-665813288f89"
#     ],
#     "id":"4020-8e2f-670fcfe6-b467-7a014292ee1c",
#     "modified":"2025-05-06T20:06:39Z",
#     "name":"TM3_SIFMAIndex2025-05-06T16:05:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-12T17:21:12Z",
#     "availableTo":"2025-12-12T17:21:12Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-12T17:15:00Z",
#     "contentTo":"2025-06-12T17:20:00Z",
#     "created":"2025-06-12T17:21:12Z",
#     "files":[
#       "492b-0fab-51dc746e-b647-c8d82443991d"
#     ],
#     "id":"4021-77af-c57ac242-9f7d-d2ba6f6458aa",
#     "modified":"2025-06-12T17:21:15Z",
#     "name":"TM3_SIFMAIndex2025-06-12T13:20:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-08T16:08:46Z",
#     "availableTo":"2025-11-08T16:08:45Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-08T16:00:00Z",
#     "contentTo":"2025-05-08T16:05:00Z",
#     "created":"2025-05-08T16:08:46Z",
#     "files":[
#       "4e69-6395-9cdad3c7-aca7-ca71fdc1602b"
#     ],
#     "id":"4026-d363-f31a9f4d-a445-cbde9df6172b",
#     "modified":"2025-05-08T16:08:49Z",
#     "name":"TM3_SIFMAIndex2025-05-08T12:05:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-05T17:32:31Z",
#     "availableTo":"2025-12-05T17:32:31Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-05T17:25:00Z",
#     "contentTo":"2025-06-05T17:30:00Z",
#     "created":"2025-06-05T17:32:31Z",
#     "files":[
#       "4826-6144-877dc546-a628-573e4ef94e30"
#     ],
#     "id":"4027-26c7-ff6c65e3-9cea-504d96c80400",
#     "modified":"2025-06-05T17:32:33Z",
#     "name":"TM3_SIFMAIndex2025-06-05T13:30:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-18T16:46:43Z",
#     "availableTo":"2025-12-18T16:46:43Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-18T16:40:00Z",
#     "contentTo":"2025-06-18T16:45:00Z",
#     "created":"2025-06-18T16:46:43Z",
#     "files":[
#       "4d78-7753-3700e60c-8dfa-37a8d3f4c954"
#     ],
#     "id":"4028-bd13-a0f80c8f-aee9-d57f2da2af25",
#     "modified":"2025-06-18T16:46:46Z",
#     "name":"TM3_SIFMAIndex2025-06-18T12:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-10T20:51:53Z",
#     "availableTo":"2025-12-10T20:51:53Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-10T20:45:00Z",
#     "contentTo":"2025-06-10T20:50:00Z",
#     "created":"2025-06-10T20:51:53Z",
#     "files":[
#       "45d0-6883-e5f9d42d-8704-6642ef6df943"
#     ],
#     "id":"4029-1a61-da6658b6-805f-1b889b10bd0b",
#     "modified":"2025-06-10T20:51:56Z",
#     "name":"TM3_SIFMAIndex2025-06-10T16:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-14T17:41:13Z",
#     "availableTo":"2025-11-14T17:41:13Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-14T17:35:00Z",
#     "contentTo":"2025-05-14T17:40:00Z",
#     "created":"2025-05-14T17:41:13Z",
#     "files":[
#       "4ef2-c0f8-adeb157d-a679-c6152277edd4"
#     ],
#     "id":"402a-24b9-9decc317-9045-bb2734724daf",
#     "modified":"2025-05-14T17:41:16Z",
#     "name":"TM3_SIFMAIndex2025-05-14T13:40:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-22T18:16:44Z",
#     "availableTo":"2025-10-22T18:16:44Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-22T18:10:00Z",
#     "contentTo":"2025-04-22T18:15:00Z",
#     "created":"2025-04-22T18:16:44Z",
#     "files":[
#       "48c2-6508-127e7d8e-90fb-281b930349ff"
#     ],
#     "id":"402b-8c4e-091deaec-b7f2-09ce02be81d8",
#     "modified":"2025-04-22T18:16:45Z",
#     "name":"TM3_SIFMAIndex2025-04-22T14:15:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-12T18:22:51Z",
#     "availableTo":"2025-12-12T18:22:51Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-12T18:15:00Z",
#     "contentTo":"2025-06-12T18:20:00Z",
#     "created":"2025-06-12T18:22:51Z",
#     "files":[
#       "47c5-b728-985f2e83-8fcd-a7c284ec6afb"
#     ],
#     "id":"402f-e99a-d4631f0c-8692-88c962bb9d65",
#     "modified":"2025-06-12T18:22:54Z",
#     "name":"TM3_SIFMAIndex2025-06-12T14:20:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-12T16:41:48Z",
#     "availableTo":"2025-12-12T16:41:48Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-12T16:35:00Z",
#     "contentTo":"2025-06-12T16:40:00Z",
#     "created":"2025-06-12T16:41:48Z",
#     "files":[
#       "47be-b0a0-3e71ec56-81b7-ba51c345c60a"
#     ],
#     "id":"402f-ee8e-490768f9-b4b6-c3e85a5597a5",
#     "modified":"2025-06-12T16:41:51Z",
#     "name":"TM3_SIFMAIndex2025-06-12T12:40:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-14T16:11:08Z",
#     "availableTo":"2025-11-14T16:11:07Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-14T16:05:00Z",
#     "contentTo":"2025-05-14T16:10:00Z",
#     "created":"2025-05-14T16:11:08Z",
#     "files":[
#       "471e-4dce-9408a2e4-826d-7670e4b7b504"
#     ],
#     "id":"4036-5866-9aa59e6d-bc37-784dd90827f0",
#     "modified":"2025-05-14T16:11:10Z",
#     "name":"TM3_SIFMAIndex2025-05-14T12:10:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-30T20:02:17Z",
#     "availableTo":"2025-10-30T20:02:17Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-30T19:55:00Z",
#     "contentTo":"2025-04-30T20:00:00Z",
#     "created":"2025-04-30T20:02:17Z",
#     "files":[
#       "48d2-3920-caa6d4a0-869d-66f579b8edad"
#     ],
#     "id":"4038-5177-ef3e1fd9-8b43-fcbf5a3e224e",
#     "modified":"2025-04-30T20:02:20Z",
#     "name":"TM3_SIFMAIndex2025-04-30T16:00:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-17T20:56:52Z",
#     "availableTo":"2025-12-17T20:56:51Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-17T20:50:00Z",
#     "contentTo":"2025-06-17T20:55:00Z",
#     "created":"2025-06-17T20:56:52Z",
#     "files":[
#       "41ff-2d9d-0480f52f-bba3-fb82d8c84e21"
#     ],
#     "id":"4039-be65-946497a4-b7b1-d9f836570be7",
#     "modified":"2025-06-17T20:56:54Z",
#     "name":"TM3_SIFMAIndex2025-06-17T16:55:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-10T16:01:24Z",
#     "availableTo":"2025-12-10T16:01:24Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-05T20:55:00Z",
#     "contentTo":"2025-06-10T16:00:00Z",
#     "created":"2025-06-10T16:01:24Z",
#     "files":[
#       "47bf-c03d-ea42a7bf-9c03-5c261a2b7a3a"
#     ],
#     "id":"403a-1ceb-f9556644-b8f0-a65dd29fcd32",
#     "modified":"2025-06-10T16:01:27Z",
#     "name":"TM3_SIFMAIndex2025-06-10T12:00:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-21T18:36:07Z",
#     "availableTo":"2025-11-21T18:36:06Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-21T18:30:00Z",
#     "contentTo":"2025-05-21T18:35:00Z",
#     "created":"2025-05-21T18:36:07Z",
#     "files":[
#       "4680-a9be-ea14a70b-8b6e-d9b1b99b0f15"
#     ],
#     "id":"403c-088f-af4001df-bc85-45ef7fdefbf2",
#     "modified":"2025-05-21T18:36:09Z",
#     "name":"TM3_SIFMAIndex2025-05-21T14:35:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-25T16:36:07Z",
#     "availableTo":"2025-12-25T16:36:06Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-25T16:30:00Z",
#     "contentTo":"2025-06-25T16:35:00Z",
#     "created":"2025-06-25T16:36:07Z",
#     "files":[
#       "4011-2134-ca2e2dcd-9c7f-79785aad67dd"
#     ],
#     "id":"4041-22d5-f30cf750-8277-9b6a4ea77274",
#     "modified":"2025-06-25T16:36:09Z",
#     "name":"TM3_SIFMAIndex2025-06-25T12:35:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-08T20:32:07Z",
#     "availableTo":"2025-11-08T20:32:06Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-08T20:25:00Z",
#     "contentTo":"2025-05-08T20:30:00Z",
#     "created":"2025-05-08T20:32:07Z",
#     "files":[
#       "4353-afe1-af62bb28-a7b7-ec34f659aefe"
#     ],
#     "id":"4044-9629-3edb6ac1-9c05-3432b451d499",
#     "modified":"2025-05-08T20:32:10Z",
#     "name":"TM3_SIFMAIndex2025-05-08T16:30:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-28T16:31:17Z",
#     "availableTo":"2025-11-28T16:31:17Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-28T16:25:00Z",
#     "contentTo":"2025-05-28T16:30:00Z",
#     "created":"2025-05-28T16:31:17Z",
#     "files":[
#       "4192-a432-74b96e63-a6d2-2682001deeff"
#     ],
#     "id":"4047-f373-a598e94c-a05a-b0da3700fe6f",
#     "modified":"2025-05-28T16:31:20Z",
#     "name":"TM3_SIFMAIndex2025-05-28T12:30:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-24T16:31:12Z",
#     "availableTo":"2025-10-24T16:31:12Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-24T16:25:00Z",
#     "contentTo":"2025-04-24T16:30:00Z",
#     "created":"2025-04-24T16:31:12Z",
#     "files":[
#       "4c05-6e40-1166199a-984d-c30ccec9182a"
#     ],
#     "id":"404f-0498-95cd27c3-81fd-6802249c9c4f",
#     "modified":"2025-04-24T16:31:15Z",
#     "name":"TM3_SIFMAIndex2025-04-24T12:30:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-29T20:46:44Z",
#     "availableTo":"2025-11-29T20:46:44Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-29T20:40:00Z",
#     "contentTo":"2025-05-29T20:45:00Z",
#     "created":"2025-05-29T20:46:44Z",
#     "files":[
#       "4995-7446-83645a6d-92ef-970d51f81ea6"
#     ],
#     "id":"404f-38d5-3a84eec0-83b4-89b9fbda4d40",
#     "modified":"2025-05-29T20:46:47Z",
#     "name":"TM3_SIFMAIndex2025-05-29T16:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-01T20:26:50Z",
#     "availableTo":"2025-11-01T20:26:50Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-01T20:20:00Z",
#     "contentTo":"2025-05-01T20:25:00Z",
#     "created":"2025-05-01T20:26:50Z",
#     "files":[
#       "48fd-26c7-10a83ee3-a240-a5df793e6f1a"
#     ],
#     "id":"4051-2f67-35a6408e-8bcc-bf739e44eefb",
#     "modified":"2025-05-01T20:26:53Z",
#     "name":"TM3_SIFMAIndex2025-05-01T16:25:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-29T18:26:35Z",
#     "availableTo":"2025-10-29T18:26:35Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-29T18:20:00Z",
#     "contentTo":"2025-04-29T18:25:00Z",
#     "created":"2025-04-29T18:26:35Z",
#     "files":[
#       "4a55-0f99-8b144f95-816f-cd1fe6ed78b9"
#     ],
#     "id":"4053-7180-3b5ff0a0-982b-65683b54ad7b",
#     "modified":"2025-04-29T18:26:38Z",
#     "name":"TM3_SIFMAIndex2025-04-29T14:25:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-20T17:01:17Z",
#     "availableTo":"2025-11-20T17:01:16Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-20T16:55:00Z",
#     "contentTo":"2025-05-20T17:00:00Z",
#     "created":"2025-05-20T17:01:17Z",
#     "files":[
#       "4c00-e7dc-def31b62-95a3-2246dfda968b"
#     ],
#     "id":"4054-5864-d2686e0a-89aa-86b34f0c74fc",
#     "modified":"2025-05-20T17:01:19Z",
#     "name":"TM3_SIFMAIndex2025-05-20T13:00:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-30T17:56:43Z",
#     "availableTo":"2025-10-30T17:56:43Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-30T17:50:00Z",
#     "contentTo":"2025-04-30T17:55:00Z",
#     "created":"2025-04-30T17:56:43Z",
#     "files":[
#       "4494-163f-2cf829b2-ac1b-5323f4daf1c6"
#     ],
#     "id":"4054-5e66-0336d28a-a617-13767dd03c64",
#     "modified":"2025-04-30T17:56:46Z",
#     "name":"TM3_SIFMAIndex2025-04-30T13:55:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-07T20:53:03Z",
#     "availableTo":"2025-11-07T20:53:03Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-07T20:45:00Z",
#     "contentTo":"2025-05-07T20:50:00Z",
#     "created":"2025-05-07T20:53:03Z",
#     "files":[
#       "44f0-eef1-60fb163b-8f24-a9d75a851acd"
#     ],
#     "id":"4058-8e94-1c62e3e7-ace6-409fd579269a",
#     "modified":"2025-05-07T20:53:06Z",
#     "name":"TM3_SIFMAIndex2025-05-07T16:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-03T18:41:23Z",
#     "availableTo":"2025-12-03T18:41:22Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-03T18:35:00Z",
#     "contentTo":"2025-06-03T18:40:00Z",
#     "created":"2025-06-03T18:41:23Z",
#     "files":[
#       "41c8-da89-a783cf68-90fd-de8f306444d0"
#     ],
#     "id":"4059-10a2-0b6078ac-b4f8-6871cf546b5c",
#     "modified":"2025-06-03T18:41:25Z",
#     "name":"TM3_SIFMAIndex2025-06-03T14:40:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-03T16:36:19Z",
#     "availableTo":"2025-12-03T16:36:19Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-03T16:30:00Z",
#     "contentTo":"2025-06-03T16:35:00Z",
#     "created":"2025-06-03T16:36:19Z",
#     "files":[
#       "4afa-5f44-e6e9dce0-8ab4-7be28df0e0c5"
#     ],
#     "id":"405a-d9e9-0b798049-9c50-250f57744c09",
#     "modified":"2025-06-03T16:36:22Z",
#     "name":"TM3_SIFMAIndex2025-06-03T12:35:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-07-09T20:56:33Z",
#     "availableTo":"2026-01-09T20:56:32Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-07-09T20:50:00Z",
#     "contentTo":"2025-07-09T20:55:00Z",
#     "created":"2025-07-09T20:56:33Z",
#     "files":[
#       "4010-b0f7-f6f130e7-a634-c0b3f172a89e"
#     ],
#     "id":"4062-09e1-26097ddb-841f-47ca5766d600",
#     "modified":"2025-07-09T20:56:36Z",
#     "name":"TM3_SIFMAIndex2025-07-09",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-26T17:11:01Z",
#     "availableTo":"2025-12-26T17:11:01Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-26T17:05:00Z",
#     "contentTo":"2025-06-26T17:10:00Z",
#     "created":"2025-06-26T17:11:01Z",
#     "files":[
#       "4740-f727-b6c9a258-a0f7-82552c0ecd8b"
#     ],
#     "id":"4063-0b50-01963e66-9c20-df80656ca47b",
#     "modified":"2025-06-26T17:11:04Z",
#     "name":"TM3_SIFMAIndex2025-06-26T13:10:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-30T20:51:25Z",
#     "availableTo":"2025-10-30T20:51:25Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-30T20:45:00Z",
#     "contentTo":"2025-04-30T20:50:00Z",
#     "created":"2025-04-30T20:51:25Z",
#     "files":[
#       "4b3f-4455-dfbf984c-98ef-c08def2f825e"
#     ],
#     "id":"4063-72c6-e8a05310-a68f-86dbae119942",
#     "modified":"2025-04-30T20:51:28Z",
#     "name":"TM3_SIFMAIndex2025-04-30T16:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-17T19:46:50Z",
#     "availableTo":"2025-10-17T19:46:49Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-17T19:40:00Z",
#     "contentTo":"2025-04-17T19:45:00Z",
#     "created":"2025-04-17T19:46:50Z",
#     "files":[
#       "4884-30fb-e306e049-8fae-c29a351fb1b8"
#     ],
#     "id":"4065-7893-f1d1ca24-b4bf-e15672774816",
#     "modified":"2025-04-17T19:46:51Z",
#     "name":"TM3_SIFMAIndex2025-04-17T15:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-07T17:53:14Z",
#     "availableTo":"2025-11-07T17:53:13Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-07T17:45:00Z",
#     "contentTo":"2025-05-07T17:50:00Z",
#     "created":"2025-05-07T17:53:14Z",
#     "files":[
#       "4781-7b21-9b053529-af56-c563c8ea06a0"
#     ],
#     "id":"4066-47a9-184885df-8395-377e618e60b9",
#     "modified":"2025-05-07T17:53:16Z",
#     "name":"TM3_SIFMAIndex2025-05-07T13:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-05T16:26:34Z",
#     "availableTo":"2025-12-05T16:26:34Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-05T16:20:00Z",
#     "contentTo":"2025-06-05T16:25:00Z",
#     "created":"2025-06-05T16:26:34Z",
#     "files":[
#       "4748-4b02-a048cce1-b33f-9277e786fe79"
#     ],
#     "id":"4066-bf28-e4318fd7-aca2-5345ca59552a",
#     "modified":"2025-06-05T16:26:37Z",
#     "name":"TM3_SIFMAIndex2025-06-05T12:25:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-11T20:41:31Z",
#     "availableTo":"2025-12-11T20:41:31Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-11T20:35:00Z",
#     "contentTo":"2025-06-11T20:40:00Z",
#     "created":"2025-06-11T20:41:31Z",
#     "files":[
#       "43c6-51fe-bc329a7d-8542-64dde06278fd"
#     ],
#     "id":"4068-334d-9293a709-8046-7af0b9151818",
#     "modified":"2025-06-11T20:41:34Z",
#     "name":"TM3_SIFMAIndex2025-06-11T16:40:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-14T17:57:00Z",
#     "availableTo":"2025-11-14T17:57:00Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-14T17:50:00Z",
#     "contentTo":"2025-05-14T17:55:00Z",
#     "created":"2025-05-14T17:57:00Z",
#     "files":[
#       "4e06-8b8d-f8eff1b6-b95a-4b8140f8c9f0"
#     ],
#     "id":"4068-c71f-2833bd01-9d04-3f296fd218e4",
#     "modified":"2025-05-14T17:57:03Z",
#     "name":"TM3_SIFMAIndex2025-05-14T13:55:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-14T18:02:09Z",
#     "availableTo":"2025-11-14T18:02:09Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-14T17:55:00Z",
#     "contentTo":"2025-05-14T18:00:00Z",
#     "created":"2025-05-14T18:02:09Z",
#     "files":[
#       "45db-3e29-06ef18e8-9e18-3ffd01814777"
#     ],
#     "id":"406d-334f-72004650-9c05-66024c03c11c",
#     "modified":"2025-05-14T18:02:11Z",
#     "name":"TM3_SIFMAIndex2025-05-14T14:00:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-18T16:01:58Z",
#     "availableTo":"2025-12-18T16:01:58Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-17T20:55:00Z",
#     "contentTo":"2025-06-18T16:00:00Z",
#     "created":"2025-06-18T16:01:58Z",
#     "files":[
#       "45b9-6b17-0fc573cc-916a-5f094eb86bcb"
#     ],
#     "id":"406f-84b8-a3365c34-a52e-e61390b11216",
#     "modified":"2025-06-18T16:02:01Z",
#     "name":"TM3_SIFMAIndex2025-06-18T12:00:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-05T19:16:59Z",
#     "availableTo":"2025-12-05T19:16:59Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-05T19:10:00Z",
#     "contentTo":"2025-06-05T19:15:00Z",
#     "created":"2025-06-05T19:16:59Z",
#     "files":[
#       "4eca-b840-775c3f81-b83b-252df1282a1c"
#     ],
#     "id":"4070-74d5-c119a550-83ef-eba488b460de",
#     "modified":"2025-06-05T19:17:02Z",
#     "name":"TM3_SIFMAIndex2025-06-05T15:15:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-06T17:52:35Z",
#     "availableTo":"2025-11-06T17:52:35Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-06T17:45:00Z",
#     "contentTo":"2025-05-06T17:50:00Z",
#     "created":"2025-05-06T17:52:35Z",
#     "files":[
#       "4d27-6686-1fe18b9e-b4b8-03e272547d45"
#     ],
#     "id":"4070-e247-7c48d559-a9fb-cc498afaef37",
#     "modified":"2025-05-06T17:52:37Z",
#     "name":"TM3_SIFMAIndex2025-05-06T13:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-28T17:36:00Z",
#     "availableTo":"2025-11-28T17:36:00Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-28T17:30:00Z",
#     "contentTo":"2025-05-28T17:35:00Z",
#     "created":"2025-05-28T17:36:00Z",
#     "files":[
#       "496b-37d2-1216a8c8-bec2-115032cf97d5"
#     ],
#     "id":"4071-7e5b-cd1bc193-9f54-747f40ef95ad",
#     "modified":"2025-05-28T17:36:03Z",
#     "name":"TM3_SIFMAIndex2025-05-28T13:35:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-24T19:16:54Z",
#     "availableTo":"2025-12-24T19:16:54Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-24T19:10:00Z",
#     "contentTo":"2025-06-24T19:15:00Z",
#     "created":"2025-06-24T19:16:54Z",
#     "files":[
#       "4a54-1b35-2b02e806-ac86-3abad408b786"
#     ],
#     "id":"4072-4475-7f3dbf51-9274-a9ba0d787803",
#     "modified":"2025-06-24T19:16:57Z",
#     "name":"TM3_SIFMAIndex2025-06-24T15:15:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-23T17:01:38Z",
#     "availableTo":"2025-10-23T17:01:38Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-23T16:55:00Z",
#     "contentTo":"2025-04-23T17:00:00Z",
#     "created":"2025-04-23T17:01:38Z",
#     "files":[
#       "4a4d-b702-896a6392-9fab-285b842625a9"
#     ],
#     "id":"4073-50cb-6c8d8b69-9b0f-a9ba34bc96ce",
#     "modified":"2025-04-23T17:01:40Z",
#     "name":"TM3_SIFMAIndex2025-04-23T13:00:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-24T18:21:13Z",
#     "availableTo":"2025-12-24T18:21:13Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-24T18:15:00Z",
#     "contentTo":"2025-06-24T18:20:00Z",
#     "created":"2025-06-24T18:21:13Z",
#     "files":[
#       "43f2-6cca-4c5d8815-abab-9bbec318ab9c"
#     ],
#     "id":"4076-b419-a0bcd84e-a36c-caa88287c349",
#     "modified":"2025-06-24T18:21:16Z",
#     "name":"TM3_SIFMAIndex2025-06-24T14:20:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-24T16:16:16Z",
#     "availableTo":"2025-12-24T16:16:16Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-24T16:10:00Z",
#     "contentTo":"2025-06-24T16:15:00Z",
#     "created":"2025-06-24T16:16:16Z",
#     "files":[
#       "43c6-c911-7a33e23d-b5c6-d0082c511a7c"
#     ],
#     "id":"4077-9142-4de43093-af0f-f0536c1d7b94",
#     "modified":"2025-06-24T16:16:19Z",
#     "name":"TM3_SIFMAIndex2025-06-24T12:15:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-24T16:36:10Z",
#     "availableTo":"2025-10-24T16:36:10Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-24T16:30:00Z",
#     "contentTo":"2025-04-24T16:35:00Z",
#     "created":"2025-04-24T16:36:10Z",
#     "files":[
#       "4475-2566-1ae34be5-8a39-469c551f694c"
#     ],
#     "id":"407d-1d8d-53b6ae02-a4c1-de97dbcb0da5",
#     "modified":"2025-04-24T16:36:13Z",
#     "name":"TM3_SIFMAIndex2025-04-24T12:35:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-13T20:51:09Z",
#     "availableTo":"2025-11-13T20:51:08Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-13T20:45:00Z",
#     "contentTo":"2025-05-13T20:50:00Z",
#     "created":"2025-05-13T20:51:09Z",
#     "files":[
#       "46a6-aade-1be77a1f-b40b-499a9cdcaeb7"
#     ],
#     "id":"407e-b1b7-65c389bc-a694-bcecb8a5eb06",
#     "modified":"2025-05-13T20:51:11Z",
#     "name":"TM3_SIFMAIndex2025-05-13T16:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-24T19:10:49Z",
#     "availableTo":"2025-12-24T19:10:48Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-24T19:05:00Z",
#     "contentTo":"2025-06-24T19:10:00Z",
#     "created":"2025-06-24T19:10:49Z",
#     "files":[
#       "4647-6372-0f95218c-ae75-e3edd7cd3101"
#     ],
#     "id":"4081-7433-777c6e1e-8b56-c96c53881cf5",
#     "modified":"2025-06-24T19:10:51Z",
#     "name":"TM3_SIFMAIndex2025-06-24T15:10:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-29T17:56:35Z",
#     "availableTo":"2025-10-29T17:56:34Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-29T17:50:00Z",
#     "contentTo":"2025-04-29T17:55:00Z",
#     "created":"2025-04-29T17:56:35Z",
#     "files":[
#       "4489-880b-fe0e0273-b254-779753422df6"
#     ],
#     "id":"4082-3f71-56dad517-9750-f7605c8f6418",
#     "modified":"2025-04-29T17:56:37Z",
#     "name":"TM3_SIFMAIndex2025-04-29T13:55:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-24T17:11:14Z",
#     "availableTo":"2025-12-24T17:11:14Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-24T17:05:00Z",
#     "contentTo":"2025-06-24T17:10:00Z",
#     "created":"2025-06-24T17:11:14Z",
#     "files":[
#       "4be4-acc5-63eda365-bf4e-74543edf933b"
#     ],
#     "id":"4085-d62f-78b95e6b-a43a-e85354809451",
#     "modified":"2025-06-24T17:11:17Z",
#     "name":"TM3_SIFMAIndex2025-06-24T13:10:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-03T18:36:07Z",
#     "availableTo":"2025-12-03T18:36:07Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-03T18:30:00Z",
#     "contentTo":"2025-06-03T18:35:00Z",
#     "created":"2025-06-03T18:36:07Z",
#     "files":[
#       "448f-6a58-c4680c18-bb91-fe8a9630a9da"
#     ],
#     "id":"4087-2a9b-f410b1ae-878d-608e4b51eb43",
#     "modified":"2025-06-03T18:36:10Z",
#     "name":"TM3_SIFMAIndex2025-06-03T14:35:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-28T16:56:45Z",
#     "availableTo":"2025-11-28T16:56:45Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-28T16:50:00Z",
#     "contentTo":"2025-05-28T16:55:00Z",
#     "created":"2025-05-28T16:56:45Z",
#     "files":[
#       "4e90-2376-6ffe580a-bafb-fb2f5e8982b3"
#     ],
#     "id":"408a-653e-54afcf04-9147-0fb9fe130ed6",
#     "modified":"2025-05-28T16:56:48Z",
#     "name":"TM3_SIFMAIndex2025-05-28T12:55:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-27T19:26:05Z",
#     "availableTo":"2025-11-27T19:26:04Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-27T19:20:00Z",
#     "contentTo":"2025-05-27T19:25:00Z",
#     "created":"2025-05-27T19:26:05Z",
#     "files":[
#       "41ef-4603-5560402e-9b12-e1eda9f84b6d"
#     ],
#     "id":"408b-82d9-d72f8780-80af-31770622ed13",
#     "modified":"2025-05-27T19:26:08Z",
#     "name":"TM3_SIFMAIndex2025-05-27T15:25:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-27T17:51:19Z",
#     "availableTo":"2025-11-27T17:51:19Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-27T17:45:00Z",
#     "contentTo":"2025-05-27T17:50:00Z",
#     "created":"2025-05-27T17:51:19Z",
#     "files":[
#       "4d22-9e3d-84d20ef9-936e-5584fbca55fe"
#     ],
#     "id":"408d-c888-11dae435-b042-5ca1f8c6a4a5",
#     "modified":"2025-05-27T17:51:22Z",
#     "name":"TM3_SIFMAIndex2025-05-27T13:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-23T20:36:17Z",
#     "availableTo":"2025-10-23T20:36:17Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-23T20:30:00Z",
#     "contentTo":"2025-04-23T20:35:00Z",
#     "created":"2025-04-23T20:36:17Z",
#     "files":[
#       "47d5-0f7e-3237b77b-8f86-c7423e97864f"
#     ],
#     "id":"408e-b283-ed129a72-b05d-02a44cbd7466",
#     "modified":"2025-04-23T20:36:18Z",
#     "name":"TM3_SIFMAIndex2025-04-23T16:35:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-22T19:51:13Z",
#     "availableTo":"2025-10-22T19:51:12Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-22T19:45:00Z",
#     "contentTo":"2025-04-22T19:50:00Z",
#     "created":"2025-04-22T19:51:13Z",
#     "files":[
#       "4cd4-817f-4c31958f-ac95-e715ab107cf2"
#     ],
#     "id":"408f-83d7-c97ebd5b-a906-8c4cc8e2d713",
#     "modified":"2025-04-22T19:51:14Z",
#     "name":"TM3_SIFMAIndex2025-04-22T15:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-04T20:51:21Z",
#     "availableTo":"2025-12-04T20:51:21Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-04T20:45:00Z",
#     "contentTo":"2025-06-04T20:50:00Z",
#     "created":"2025-06-04T20:51:21Z",
#     "files":[
#       "410c-3062-cfaf8e6e-8820-763de9094d2d"
#     ],
#     "id":"4091-07f3-96998d71-8867-fa2890c98250",
#     "modified":"2025-06-04T20:51:24Z",
#     "name":"TM3_SIFMAIndex2025-06-04T16:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-28T19:41:33Z",
#     "availableTo":"2025-11-28T19:41:33Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-28T19:35:00Z",
#     "contentTo":"2025-05-28T19:40:00Z",
#     "created":"2025-05-28T19:41:33Z",
#     "files":[
#       "4432-f595-dd5d7e48-b25b-5e9a7b66d74a"
#     ],
#     "id":"409a-032a-6287357f-8ab8-bd893b504162",
#     "modified":"2025-05-28T19:41:35Z",
#     "name":"TM3_SIFMAIndex2025-05-28T15:40:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-12T18:17:06Z",
#     "availableTo":"2025-12-12T18:17:06Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-12T18:10:00Z",
#     "contentTo":"2025-06-12T18:15:00Z",
#     "created":"2025-06-12T18:17:06Z",
#     "files":[
#       "4ab7-828d-4384e49b-b9af-7162c7718542"
#     ],
#     "id":"409b-80c0-6c9da68a-8ff3-e1889986cf71",
#     "modified":"2025-06-12T18:17:09Z",
#     "name":"TM3_SIFMAIndex2025-06-12T14:15:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-26T16:27:05Z",
#     "availableTo":"2025-12-26T16:27:04Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-26T16:20:00Z",
#     "contentTo":"2025-06-26T16:25:00Z",
#     "created":"2025-06-26T16:27:05Z",
#     "files":[
#       "421e-e158-60092087-b0b7-1a847978960d"
#     ],
#     "id":"409b-a054-8ed161a6-9eda-8df5ab33d7e3",
#     "modified":"2025-06-26T16:27:07Z",
#     "name":"TM3_SIFMAIndex2025-06-26T12:25:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-28T18:21:35Z",
#     "availableTo":"2025-11-28T18:21:35Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-28T18:15:00Z",
#     "contentTo":"2025-05-28T18:20:00Z",
#     "created":"2025-05-28T18:21:35Z",
#     "files":[
#       "4ea0-02db-e9d1621b-98cb-ca932431727f"
#     ],
#     "id":"409c-4be9-207ba790-b356-8681a0096206",
#     "modified":"2025-05-28T18:21:38Z",
#     "name":"TM3_SIFMAIndex2025-05-28T14:20:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-21T18:26:20Z",
#     "availableTo":"2025-11-21T18:26:20Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-21T18:20:00Z",
#     "contentTo":"2025-05-21T18:25:00Z",
#     "created":"2025-05-21T18:26:20Z",
#     "files":[
#       "4e44-601e-54400a76-88a3-04236a751fd5"
#     ],
#     "id":"409f-6dc7-e53b231a-94de-68028b0cc331",
#     "modified":"2025-05-21T18:26:23Z",
#     "name":"TM3_SIFMAIndex2025-05-21T14:25:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-05T16:46:13Z",
#     "availableTo":"2025-12-05T16:46:13Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-05T16:40:00Z",
#     "contentTo":"2025-06-05T16:45:00Z",
#     "created":"2025-06-05T16:46:13Z",
#     "files":[
#       "43db-38b9-f39f9f3a-8827-7e4113e81aea"
#     ],
#     "id":"40a2-a882-8f656deb-9dd5-6f4ddee5c0f8",
#     "modified":"2025-06-05T16:46:16Z",
#     "name":"TM3_SIFMAIndex2025-06-05T12:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-17T16:51:37Z",
#     "availableTo":"2025-10-17T16:51:37Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-17T16:45:00Z",
#     "contentTo":"2025-04-17T16:50:00Z",
#     "created":"2025-04-17T16:51:37Z",
#     "files":[
#       "4098-727a-a8c3aa0b-aa27-5677a19bf74b"
#     ],
#     "id":"40a2-dc4e-0f7d9887-822f-8881ae0fa04f",
#     "modified":"2025-04-17T16:51:38Z",
#     "name":"TM3_SIFMAIndex2025-04-17T12:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-15T19:21:14Z",
#     "availableTo":"2025-11-15T19:21:13Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-15T19:15:00Z",
#     "contentTo":"2025-05-15T19:20:00Z",
#     "created":"2025-05-15T19:21:14Z",
#     "files":[
#       "49b6-f583-3586caee-8092-bf7d2b2f05e2"
#     ],
#     "id":"40a6-f833-21c659f6-a0e3-b7c8b19cee66",
#     "modified":"2025-05-15T19:21:16Z",
#     "name":"TM3_SIFMAIndex2025-05-15T15:20:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-03T17:32:32Z",
#     "availableTo":"2025-12-03T17:32:32Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-03T17:25:00Z",
#     "contentTo":"2025-06-03T17:30:00Z",
#     "created":"2025-06-03T17:32:32Z",
#     "files":[
#       "42b6-6fe5-561c295d-9901-9466d0f56841"
#     ],
#     "id":"40a7-e918-4b26e60d-978b-cf312a91c57f",
#     "modified":"2025-06-03T17:32:35Z",
#     "name":"TM3_SIFMAIndex2025-06-03T13:30:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-28T19:50:49Z",
#     "availableTo":"2025-11-28T19:50:49Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-28T19:45:00Z",
#     "contentTo":"2025-05-28T19:50:00Z",
#     "created":"2025-05-28T19:50:49Z",
#     "files":[
#       "4d90-9858-e606da9c-bcc0-dfc867852dcd"
#     ],
#     "id":"40a8-076c-1286c804-8d9d-263e881092ad",
#     "modified":"2025-05-28T19:50:52Z",
#     "name":"TM3_SIFMAIndex2025-05-28T15:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-03T20:46:46Z",
#     "availableTo":"2025-12-03T20:46:46Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-03T20:40:00Z",
#     "contentTo":"2025-06-03T20:45:00Z",
#     "created":"2025-06-03T20:46:46Z",
#     "files":[
#       "4392-e1c5-e469155a-b560-61082bab88c1"
#     ],
#     "id":"40a9-8613-195c8551-bf0c-79842d43d523",
#     "modified":"2025-06-03T20:46:49Z",
#     "name":"TM3_SIFMAIndex2025-06-03T16:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-29T18:42:12Z",
#     "availableTo":"2025-11-29T18:42:11Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-29T18:35:00Z",
#     "contentTo":"2025-05-29T18:40:00Z",
#     "created":"2025-05-29T18:42:12Z",
#     "files":[
#       "4670-8f8e-96dbd0b6-ad8e-404fca99bd38"
#     ],
#     "id":"40a9-c575-0d5ee819-892d-fd5c3e54d560",
#     "modified":"2025-05-29T18:42:15Z",
#     "name":"TM3_SIFMAIndex2025-05-29T14:40:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-29T17:41:31Z",
#     "availableTo":"2025-10-29T17:41:30Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-29T17:35:00Z",
#     "contentTo":"2025-04-29T17:40:00Z",
#     "created":"2025-04-29T17:41:31Z",
#     "files":[
#       "497f-929f-28815812-a5ba-eb44f5e0b14c"
#     ],
#     "id":"40aa-5c06-7df4bfbc-bc7a-7636765852b4",
#     "modified":"2025-04-29T17:41:33Z",
#     "name":"TM3_SIFMAIndex2025-04-29T13:40:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-10T17:56:09Z",
#     "availableTo":"2025-12-10T17:56:09Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-10T17:50:00Z",
#     "contentTo":"2025-06-10T17:55:00Z",
#     "created":"2025-06-10T17:56:09Z",
#     "files":[
#       "4c39-a9a5-ec64bdae-a8a2-83f010c0edba"
#     ],
#     "id":"40ac-df60-7815ce4a-9fed-ce3020eea39e",
#     "modified":"2025-06-10T17:56:12Z",
#     "name":"TM3_SIFMAIndex2025-06-10T13:55:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-05T19:46:29Z",
#     "availableTo":"2025-12-05T19:46:28Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-05T19:40:00Z",
#     "contentTo":"2025-06-05T19:45:00Z",
#     "created":"2025-06-05T19:46:29Z",
#     "files":[
#       "41b3-e887-9d4fc647-bb66-5071716ba26e"
#     ],
#     "id":"40ae-15e8-0ea3d7bc-8db5-404cc178f028",
#     "modified":"2025-06-05T19:46:31Z",
#     "name":"TM3_SIFMAIndex2025-06-05T15:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-29T20:41:21Z",
#     "availableTo":"2025-11-29T20:41:21Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-29T20:35:00Z",
#     "contentTo":"2025-05-29T20:40:00Z",
#     "created":"2025-05-29T20:41:21Z",
#     "files":[
#       "4e97-da20-bd64267f-8259-9e77403a96c9"
#     ],
#     "id":"40ae-94d4-0aec9413-a644-a1fb9a052615",
#     "modified":"2025-05-29T20:41:24Z",
#     "name":"TM3_SIFMAIndex2025-05-29T16:40:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-19T20:31:54Z",
#     "availableTo":"2025-12-19T20:31:53Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-19T20:25:00Z",
#     "contentTo":"2025-06-19T20:30:00Z",
#     "created":"2025-06-19T20:31:54Z",
#     "files":[
#       "41af-02e3-493a5186-a4d8-cb818ef48903"
#     ],
#     "id":"40af-9069-aa0e4377-9245-d43b0acd73df",
#     "modified":"2025-06-19T20:31:56Z",
#     "name":"TM3_SIFMAIndex2025-06-19T16:30:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-21T16:11:20Z",
#     "availableTo":"2025-11-21T16:11:20Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-21T16:05:00Z",
#     "contentTo":"2025-05-21T16:10:00Z",
#     "created":"2025-05-21T16:11:20Z",
#     "files":[
#       "4fb3-9ee0-ac6992b0-8f21-d0a34a352cf0"
#     ],
#     "id":"40b1-5863-53a19905-924d-d7ac9968cada",
#     "modified":"2025-05-21T16:11:23Z",
#     "name":"TM3_SIFMAIndex2025-05-21T12:10:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-28T20:20:48Z",
#     "availableTo":"2025-11-28T20:20:47Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-28T20:15:00Z",
#     "contentTo":"2025-05-28T20:20:00Z",
#     "created":"2025-05-28T20:20:48Z",
#     "files":[
#       "4822-67b5-a15c83d8-a875-1804274119cf"
#     ],
#     "id":"40b1-de13-c8ca4890-bcf2-c726390a528c",
#     "modified":"2025-05-28T20:20:51Z",
#     "name":"TM3_SIFMAIndex2025-05-28T16:20:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-17T20:31:42Z",
#     "availableTo":"2025-10-17T20:31:42Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-17T20:25:00Z",
#     "contentTo":"2025-04-17T20:30:00Z",
#     "created":"2025-04-17T20:31:42Z",
#     "files":[
#       "4820-3517-fbc63a63-9886-01532b902525"
#     ],
#     "id":"40b4-2198-048bf9c0-8c51-cb405f0f4129",
#     "modified":"2025-04-17T20:31:44Z",
#     "name":"TM3_SIFMAIndex2025-04-17T16:30:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-11T16:51:21Z",
#     "availableTo":"2025-12-11T16:51:21Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-11T16:45:00Z",
#     "contentTo":"2025-06-11T16:50:00Z",
#     "created":"2025-06-11T16:51:21Z",
#     "files":[
#       "4bea-28d3-9c7f2a5f-949a-6bc5171abbc1"
#     ],
#     "id":"40b5-3892-936aac16-b9aa-aa628e10479d",
#     "modified":"2025-06-11T16:51:24Z",
#     "name":"TM3_SIFMAIndex2025-06-11T12:50:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-17T20:47:03Z",
#     "availableTo":"2025-12-17T20:47:03Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-17T20:40:00Z",
#     "contentTo":"2025-06-17T20:45:00Z",
#     "created":"2025-06-17T20:47:03Z",
#     "files":[
#       "47b3-b8f7-1db6ddf8-8db1-75078e8ab939"
#     ],
#     "id":"40bb-08ec-35b82d24-b078-1ec18a52878a",
#     "modified":"2025-06-17T20:47:06Z",
#     "name":"TM3_SIFMAIndex2025-06-17T16:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-11T18:46:29Z",
#     "availableTo":"2025-12-11T18:46:29Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-11T18:40:00Z",
#     "contentTo":"2025-06-11T18:45:00Z",
#     "created":"2025-06-11T18:46:29Z",
#     "files":[
#       "4cce-4370-ca9b93c5-8ecf-35bdc5cbd56f"
#     ],
#     "id":"40bb-3e9d-543f5031-9cfd-2c0599505036",
#     "modified":"2025-06-11T18:46:32Z",
#     "name":"TM3_SIFMAIndex2025-06-11T14:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-30T17:17:19Z",
#     "availableTo":"2025-10-30T17:17:19Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-30T17:10:00Z",
#     "contentTo":"2025-04-30T17:15:00Z",
#     "created":"2025-04-30T17:17:19Z",
#     "files":[
#       "4a93-d074-3ca270ba-8e0d-303aeb2aa782"
#     ],
#     "id":"40bc-f626-bf031377-9f1f-497b19aab121",
#     "modified":"2025-04-30T17:17:22Z",
#     "name":"TM3_SIFMAIndex2025-04-30T13:15:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-30T16:46:06Z",
#     "availableTo":"2025-10-30T16:46:06Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-30T16:40:00Z",
#     "contentTo":"2025-04-30T16:45:00Z",
#     "created":"2025-04-30T16:46:06Z",
#     "files":[
#       "406d-026a-ad51c176-8692-3f2b6c1c1362"
#     ],
#     "id":"40be-25d3-053de665-a520-8b93ad8f7ca1",
#     "modified":"2025-04-30T16:46:09Z",
#     "name":"TM3_SIFMAIndex2025-04-30T12:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-24T17:46:32Z",
#     "availableTo":"2025-10-24T17:46:31Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-24T17:40:00Z",
#     "contentTo":"2025-04-24T17:45:00Z",
#     "created":"2025-04-24T17:46:32Z",
#     "files":[
#       "4f50-d0f4-ede4c763-a712-25437c0ef2ed"
#     ],
#     "id":"40bf-5172-b695e84c-adfe-a463a64c09c9",
#     "modified":"2025-04-24T17:46:34Z",
#     "name":"TM3_SIFMAIndex2025-04-24T13:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-14T18:11:33Z",
#     "availableTo":"2025-11-14T18:11:32Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-14T18:05:00Z",
#     "contentTo":"2025-05-14T18:10:00Z",
#     "created":"2025-05-14T18:11:33Z",
#     "files":[
#       "4be0-7c1b-8f3d9e44-b6ca-b401657c0443"
#     ],
#     "id":"40c7-5e7b-374bf3f0-9d1a-0a37ae3c369e",
#     "modified":"2025-05-14T18:11:36Z",
#     "name":"TM3_SIFMAIndex2025-05-14T14:10:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-14T17:16:05Z",
#     "availableTo":"2025-11-14T17:16:05Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-14T17:10:00Z",
#     "contentTo":"2025-05-14T17:15:00Z",
#     "created":"2025-05-14T17:16:05Z",
#     "files":[
#       "43e0-4f22-1bb49ddf-a968-b9a17af76725"
#     ],
#     "id":"40c9-f0ff-6c5d4375-b556-a004fdfeae02",
#     "modified":"2025-05-14T17:16:08Z",
#     "name":"TM3_SIFMAIndex2025-05-14T13:15:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-13T20:21:03Z",
#     "availableTo":"2025-11-13T20:21:02Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-13T20:15:00Z",
#     "contentTo":"2025-05-13T20:20:00Z",
#     "created":"2025-05-13T20:21:03Z",
#     "files":[
#       "4409-0743-9093dd7f-a899-518a35b3f8e0"
#     ],
#     "id":"40ca-95c0-f73ac129-8310-e29f05286653",
#     "modified":"2025-05-13T20:21:06Z",
#     "name":"TM3_SIFMAIndex2025-05-13T16:20:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-07T16:47:53Z",
#     "availableTo":"2025-11-07T16:47:52Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-07T16:40:00Z",
#     "contentTo":"2025-05-07T16:45:00Z",
#     "created":"2025-05-07T16:47:53Z",
#     "files":[
#       "4e04-44a5-67ade9c0-a3d8-7f33944559b1"
#     ],
#     "id":"40ca-cb88-06d69a72-ae21-dc6cba91a87d",
#     "modified":"2025-05-07T16:47:55Z",
#     "name":"TM3_SIFMAIndex2025-05-07T12:45:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-04-24T16:11:29Z",
#     "availableTo":"2025-10-24T16:11:28Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-04-24T16:05:00Z",
#     "contentTo":"2025-04-24T16:10:00Z",
#     "created":"2025-04-24T16:11:29Z",
#     "files":[
#       "49bb-d8ab-73518718-ba96-eddbb1f2618f"
#     ],
#     "id":"40cb-3630-fd6a8b1b-8c55-10ae3d2ba00f",
#     "modified":"2025-04-24T16:11:31Z",
#     "name":"TM3_SIFMAIndex2025-04-24T12:10:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-17T18:16:39Z",
#     "availableTo":"2025-12-17T18:16:39Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-17T18:10:00Z",
#     "contentTo":"2025-06-17T18:15:00Z",
#     "created":"2025-06-17T18:16:39Z",
#     "files":[
#       "4d16-1dfa-7a4479bb-b09c-528b517248dc"
#     ],
#     "id":"40ce-cb00-4fb5e61d-b7c4-b64c5eeffe7d",
#     "modified":"2025-06-17T18:16:42Z",
#     "name":"TM3_SIFMAIndex2025-06-17T14:15:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-05-14T19:41:24Z",
#     "availableTo":"2025-11-14T19:41:24Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-05-14T19:35:00Z",
#     "contentTo":"2025-05-14T19:40:00Z",
#     "created":"2025-05-14T19:41:24Z",
#     "files":[
#       "46d2-cdb7-74152835-92aa-7b63d35e350c"
#     ],
#     "id":"40cf-03d0-6b5ddbe5-9a66-f5974b635198",
#     "modified":"2025-05-14T19:41:27Z",
#     "name":"TM3_SIFMAIndex2025-05-14T15:40:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-10T20:41:17Z",
#     "availableTo":"2025-12-10T20:41:17Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-10T20:35:00Z",
#     "contentTo":"2025-06-10T20:40:00Z",
#     "created":"2025-06-10T20:41:17Z",
#     "files":[
#       "41c7-46e1-fa35cc97-884d-980b11395e84"
#     ],
#     "id":"40d0-d848-813d58d6-a6d1-05519f086db7",
#     "modified":"2025-06-10T20:41:20Z",
#     "name":"TM3_SIFMAIndex2025-06-10T16:40:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   },
#   {
#     "attributes":[],
#     "availableFrom":"2025-06-17T19:21:43Z",
#     "availableTo":"2025-12-17T19:21:43Z",
#     "bucketName":"bulk-custom",
#     "contentFrom":"2025-06-17T19:15:00Z",
#     "contentTo":"2025-06-17T19:20:00Z",
#     "created":"2025-06-17T19:21:43Z",
#     "files":[
#       "46d2-8e62-a58e26ce-88b9-b27afc78ab2a"
#     ],
#     "id":"40d4-4200-76be5a75-995f-e44c49551381",
#     "modified":"2025-06-17T19:21:46Z",
#     "name":"TM3_SIFMAIndex2025-06-17T15:20:00.000-04:00",
#     "numFiles":1,
#     "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#     "status":"READY"
#   }
# ]

# %% [markdown]
# #### The FileSets can be more than 100!!
#
# Please note that the FileSets can be more than 100 records. The API returns data maximum 100 records per one query.
#
# If the there are more than 100 records, the API returns the ```@nextLink``` node which contains the URL for requesting the next page of query as follows:
#
# ```HTTP
# GET {@nextLink URL}, HTTP/1.1
# Host: api.refinitiv.com
# Authorization: Bearer <Access Token>
# ```

# %%
if '@nextLink' in fileSet_response.json():
    next_link = fileSet_response.json()['@nextLink']
    print(next_link)
# Out:
# /file-store/v1/file-sets?bucket=bulk-Custom&packageId=4a2f-a444-b1f4a145-b0f9-4509ed361868&pageSize=100&skipToken=ZmlsZXNldElkPTQwZDQtNDIwMC03NmJlNWE3NS05OTVmLWU0NGM0OTU1MTM4MQ

# %% [markdown]
# You can use ```@nextLink``` to the URL of the HTTP Request GET Method.

# %%
if '@nextLink' in fileSet_response.json():
    next_link = fileSet_response.json()['@nextLink']
    CFS_url = f'{RDP_HOST}{next_link}'
    
    try:
        fileSet_response = requests.get(CFS_url, headers={'Authorization': f'Bearer {access_token}'})
    except requests.exceptions.RequestException as exp:
        print(f'Caught exception: {exp}')
    
    if fileSet_response.status_code == 200:  # HTTP Status 'OK'
        print('Receive list Package IDs from RDP APIs')
    else:
        print(f'RDP APIs: CFS request failure: {fileSet_response.status_code} {fileSet_response.reason}')
        print(f'Text: {fileSet_response.text}')
# Out:
# Receive list Package IDs from RDP APIs

# %%
print(json.dumps(fileSet_response.json(), sort_keys=True, indent=2, separators=(',', ':')))
# Out:
# {
#   "@nextLink":"/file-store/v1/file-sets?bucket=bulk-Custom&skipToken=ZmlsZXNldElkPTQxYmQtMTQxOS02Y2UxNDRjZC1hYWNmLTI1YjE2YWExMDllYQ&packageId=4a2f-a444-b1f4a145-b0f9-4509ed361868&pageSize=100",
#   "value":[
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-10T20:35:48Z",
#       "availableTo":"2025-12-10T20:35:48Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-10T20:30:00Z",
#       "contentTo":"2025-06-10T20:35:00Z",
#       "created":"2025-06-10T20:35:48Z",
#       "files":[
#         "44ab-6f74-31d12807-9aab-4a642aed55b4"
#       ],
#       "id":"40d5-9a88-07d52b89-8a36-55eb30b62bea",
#       "modified":"2025-06-10T20:35:51Z",
#       "name":"TM3_SIFMAIndex2025-06-10T16:35:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-03T18:51:33Z",
#       "availableTo":"2025-12-03T18:51:33Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-03T18:45:00Z",
#       "contentTo":"2025-06-03T18:50:00Z",
#       "created":"2025-06-03T18:51:33Z",
#       "files":[
#         "4e00-e18b-6bf14ea2-97ad-bde8dd43b0e2"
#       ],
#       "id":"40d6-d223-c0942f80-894f-0a4a21768a09",
#       "modified":"2025-06-03T18:51:36Z",
#       "name":"TM3_SIFMAIndex2025-06-03T14:50:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-29T19:32:01Z",
#       "availableTo":"2025-10-29T19:32:01Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-29T19:25:00Z",
#       "contentTo":"2025-04-29T19:30:00Z",
#       "created":"2025-04-29T19:32:01Z",
#       "files":[
#         "44a8-f334-c97ff4be-b823-b13102842376"
#       ],
#       "id":"40d8-8405-ca7788d9-9087-2a2638d97cca",
#       "modified":"2025-04-29T19:32:04Z",
#       "name":"TM3_SIFMAIndex2025-04-29T15:30:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-12T17:16:52Z",
#       "availableTo":"2025-12-12T17:16:52Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-12T17:10:00Z",
#       "contentTo":"2025-06-12T17:15:00Z",
#       "created":"2025-06-12T17:16:52Z",
#       "files":[
#         "4c84-54f1-19a2eaec-815f-98e9e8848816"
#       ],
#       "id":"40d8-ff86-a00c51b4-8e76-ff3e02043df4",
#       "modified":"2025-06-12T17:16:55Z",
#       "name":"TM3_SIFMAIndex2025-06-12T13:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-04T17:05:58Z",
#       "availableTo":"2025-12-04T17:05:58Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-04T17:00:00Z",
#       "contentTo":"2025-06-04T17:05:00Z",
#       "created":"2025-06-04T17:05:58Z",
#       "files":[
#         "4d78-1323-7a4f5693-9f88-ce9edd7495a8"
#       ],
#       "id":"40dd-c367-109aab60-9e2a-ca1cc27788a1",
#       "modified":"2025-06-04T17:06:01Z",
#       "name":"TM3_SIFMAIndex2025-06-04T13:05:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-18T18:46:10Z",
#       "availableTo":"2025-12-18T18:46:10Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-18T18:40:00Z",
#       "contentTo":"2025-06-18T18:45:00Z",
#       "created":"2025-06-18T18:46:10Z",
#       "files":[
#         "48c0-bdaf-14cb32f0-a129-016e5054eaa1"
#       ],
#       "id":"40e7-f1f7-432ea5f4-b1c1-3682dfbe26bb",
#       "modified":"2025-06-18T18:46:13Z",
#       "name":"TM3_SIFMAIndex2025-06-18T14:45:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-19T20:46:29Z",
#       "availableTo":"2025-12-19T20:46:29Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-19T20:40:00Z",
#       "contentTo":"2025-06-19T20:45:00Z",
#       "created":"2025-06-19T20:46:29Z",
#       "files":[
#         "4fa4-4e19-5431bbcf-ba3f-70d137f026fd"
#       ],
#       "id":"40e8-a0fc-76933036-b88d-aef5bd19d219",
#       "modified":"2025-06-19T20:46:32Z",
#       "name":"TM3_SIFMAIndex2025-06-19T16:45:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-15T18:51:26Z",
#       "availableTo":"2025-11-15T18:51:25Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-15T18:45:00Z",
#       "contentTo":"2025-05-15T18:50:00Z",
#       "created":"2025-05-15T18:51:26Z",
#       "files":[
#         "49dc-19e3-cf9c8835-9ee3-a0985a0d6549"
#       ],
#       "id":"40ea-1fe3-a13083d4-ab88-aed586ac2e5d",
#       "modified":"2025-05-15T18:51:28Z",
#       "name":"TM3_SIFMAIndex2025-05-15T14:50:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-06T16:01:32Z",
#       "availableTo":"2025-11-06T16:01:32Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-01T20:55:00Z",
#       "contentTo":"2025-05-06T16:00:00Z",
#       "created":"2025-05-06T16:01:32Z",
#       "files":[
#         "445c-91f7-e68d81b1-b406-11601c4586f0"
#       ],
#       "id":"40ed-6eab-24ba421c-a971-2ab92a23e29e",
#       "modified":"2025-05-06T16:01:35Z",
#       "name":"TM3_SIFMAIndex2025-05-06T12:00:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-21T19:46:28Z",
#       "availableTo":"2025-11-21T19:46:28Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-21T19:40:00Z",
#       "contentTo":"2025-05-21T19:45:00Z",
#       "created":"2025-05-21T19:46:28Z",
#       "files":[
#         "453a-8f6b-e21d672a-aa0c-f916a38bccfd"
#       ],
#       "id":"40ef-52c4-e9fa48b9-b865-14a7c24ac30a",
#       "modified":"2025-05-21T19:46:31Z",
#       "name":"TM3_SIFMAIndex2025-05-21T15:45:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-03T18:30:58Z",
#       "availableTo":"2025-12-03T18:30:58Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-03T18:25:00Z",
#       "contentTo":"2025-06-03T18:30:00Z",
#       "created":"2025-06-03T18:30:58Z",
#       "files":[
#         "43f9-7726-a518c8fd-906a-67f503bc4c03"
#       ],
#       "id":"40f1-64e0-e4c88ca3-891e-f5b871b68e40",
#       "modified":"2025-06-03T18:31:01Z",
#       "name":"TM3_SIFMAIndex2025-06-03T14:30:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-17T18:56:30Z",
#       "availableTo":"2025-10-17T18:56:30Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-17T18:50:00Z",
#       "contentTo":"2025-04-17T18:55:00Z",
#       "created":"2025-04-17T18:56:30Z",
#       "files":[
#         "4509-71d0-5fa592b4-a244-dded74376b7b"
#       ],
#       "id":"40f2-48de-cfebdd89-85dd-2680b9158792",
#       "modified":"2025-04-17T18:56:32Z",
#       "name":"TM3_SIFMAIndex2025-04-17T14:55:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-29T16:46:16Z",
#       "availableTo":"2025-10-29T16:46:15Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-29T16:40:00Z",
#       "contentTo":"2025-04-29T16:45:00Z",
#       "created":"2025-04-29T16:46:16Z",
#       "files":[
#         "4675-7735-61f858f1-be81-69ed0dc250de"
#       ],
#       "id":"40f8-182b-50507439-a589-803af9173414",
#       "modified":"2025-04-29T16:46:18Z",
#       "name":"TM3_SIFMAIndex2025-04-29T12:45:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-28T19:31:24Z",
#       "availableTo":"2025-11-28T19:31:23Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-28T19:25:00Z",
#       "contentTo":"2025-05-28T19:30:00Z",
#       "created":"2025-05-28T19:31:24Z",
#       "files":[
#         "411d-474f-0d04c41a-8c55-90876637cd34"
#       ],
#       "id":"40f8-c8bb-26446489-b23d-1caf3fc63225",
#       "modified":"2025-05-28T19:31:26Z",
#       "name":"TM3_SIFMAIndex2025-05-28T15:30:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-12T19:10:48Z",
#       "availableTo":"2025-12-12T19:10:48Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-12T19:05:00Z",
#       "contentTo":"2025-06-12T19:10:00Z",
#       "created":"2025-06-12T19:10:48Z",
#       "files":[
#         "41a6-7010-496cbd83-9c3a-f6f1bb9d6f47"
#       ],
#       "id":"40f8-de84-a879af0d-a8a6-37cc6f98fe55",
#       "modified":"2025-06-12T19:10:51Z",
#       "name":"TM3_SIFMAIndex2025-06-12T15:10:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-06T18:07:56Z",
#       "availableTo":"2025-11-06T18:07:55Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-06T18:00:00Z",
#       "contentTo":"2025-05-06T18:05:00Z",
#       "created":"2025-05-06T18:07:56Z",
#       "files":[
#         "42dc-05d2-79b0bf8c-a38c-af7f853e075e"
#       ],
#       "id":"40fa-049e-4d4175e1-85e5-828b269af655",
#       "modified":"2025-05-06T18:07:58Z",
#       "name":"TM3_SIFMAIndex2025-05-06T14:05:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-05T19:31:28Z",
#       "availableTo":"2025-12-05T19:31:28Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-05T19:25:00Z",
#       "contentTo":"2025-06-05T19:30:00Z",
#       "created":"2025-06-05T19:31:28Z",
#       "files":[
#         "4d62-4cad-6b8ebbaf-b207-9193ac3f5e2c"
#       ],
#       "id":"40fe-ef15-6fe0daee-bb70-736684b8d35a",
#       "modified":"2025-06-05T19:31:31Z",
#       "name":"TM3_SIFMAIndex2025-06-05T15:30:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-07T18:12:33Z",
#       "availableTo":"2025-11-07T18:12:32Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-07T18:05:00Z",
#       "contentTo":"2025-05-07T18:10:00Z",
#       "created":"2025-05-07T18:12:33Z",
#       "files":[
#         "4f2e-7435-e7b86568-8bd7-87c4367f009f"
#       ],
#       "id":"40ff-7cd3-ae6d39aa-aea0-0a0cdbdac7ea",
#       "modified":"2025-05-07T18:12:35Z",
#       "name":"TM3_SIFMAIndex2025-05-07T14:10:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-29T19:05:53Z",
#       "availableTo":"2025-10-29T19:05:53Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-29T19:00:00Z",
#       "contentTo":"2025-04-29T19:05:00Z",
#       "created":"2025-04-29T19:05:53Z",
#       "files":[
#         "445a-4619-7d869f13-829e-94d365696606"
#       ],
#       "id":"4103-0281-87174e2b-b21d-e046eb4681c2",
#       "modified":"2025-04-29T19:05:56Z",
#       "name":"TM3_SIFMAIndex2025-04-29T15:05:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-29T17:21:18Z",
#       "availableTo":"2025-10-29T17:21:17Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-29T17:15:00Z",
#       "contentTo":"2025-04-29T17:20:00Z",
#       "created":"2025-04-29T17:21:18Z",
#       "files":[
#         "46a2-7f0f-7d2c3ad7-878d-3dc680571a8d"
#       ],
#       "id":"4105-b9e6-7552f069-b1fd-71958de8f6d8",
#       "modified":"2025-04-29T17:21:20Z",
#       "name":"TM3_SIFMAIndex2025-04-29T13:20:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-24T17:16:55Z",
#       "availableTo":"2025-12-24T17:16:55Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-24T17:10:00Z",
#       "contentTo":"2025-06-24T17:15:00Z",
#       "created":"2025-06-24T17:16:55Z",
#       "files":[
#         "4088-45b9-97306b82-9970-56dfb9db4d83"
#       ],
#       "id":"4105-cf1f-359731de-b57c-738c0e015d12",
#       "modified":"2025-06-24T17:16:59Z",
#       "name":"TM3_SIFMAIndex2025-06-24T13:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-06T17:06:55Z",
#       "availableTo":"2025-11-06T17:06:55Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-06T17:00:00Z",
#       "contentTo":"2025-05-06T17:05:00Z",
#       "created":"2025-05-06T17:06:55Z",
#       "files":[
#         "4c44-b050-516bde1c-a69b-ad40fb967990"
#       ],
#       "id":"4107-e438-512a54f8-944e-3bfc98680f90",
#       "modified":"2025-05-06T17:06:58Z",
#       "name":"TM3_SIFMAIndex2025-05-06T13:05:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-06T16:36:17Z",
#       "availableTo":"2025-11-06T16:36:16Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-06T16:30:00Z",
#       "contentTo":"2025-05-06T16:35:00Z",
#       "created":"2025-05-06T16:36:17Z",
#       "files":[
#         "4e88-3ba1-08104cce-bc79-d9923a500443"
#       ],
#       "id":"410b-2b69-e5ce4f2b-91c5-99b94a0a95c0",
#       "modified":"2025-05-06T16:36:19Z",
#       "name":"TM3_SIFMAIndex2025-05-06T12:35:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-06T17:47:44Z",
#       "availableTo":"2025-11-06T17:47:43Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-06T17:40:00Z",
#       "contentTo":"2025-05-06T17:45:00Z",
#       "created":"2025-05-06T17:47:44Z",
#       "files":[
#         "4c54-0c34-2850e6ac-874b-17eb47aa3ed4"
#       ],
#       "id":"4110-533a-65896ed6-a108-e4676a59ce8b",
#       "modified":"2025-05-06T17:47:46Z",
#       "name":"TM3_SIFMAIndex2025-05-06T13:45:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-22T20:51:44Z",
#       "availableTo":"2025-10-22T20:51:43Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-22T20:45:00Z",
#       "contentTo":"2025-04-22T20:50:00Z",
#       "created":"2025-04-22T20:51:44Z",
#       "files":[
#         "49a0-e211-716f2698-a720-6d877dd437ed"
#       ],
#       "id":"4111-123a-73d99f54-8d78-90e5df69f5e5",
#       "modified":"2025-04-22T20:51:45Z",
#       "name":"TM3_SIFMAIndex2025-04-22T16:50:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-19T16:51:28Z",
#       "availableTo":"2025-12-19T16:51:28Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-19T16:45:00Z",
#       "contentTo":"2025-06-19T16:50:00Z",
#       "created":"2025-06-19T16:51:28Z",
#       "files":[
#         "4449-acc0-9d5d6c75-abf4-122312735eeb"
#       ],
#       "id":"4112-90d4-1408e204-b87e-d9a8c39ad757",
#       "modified":"2025-06-19T16:51:31Z",
#       "name":"TM3_SIFMAIndex2025-06-19T12:50:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-14T18:36:06Z",
#       "availableTo":"2025-11-14T18:36:06Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-14T18:30:00Z",
#       "contentTo":"2025-05-14T18:35:00Z",
#       "created":"2025-05-14T18:36:06Z",
#       "files":[
#         "4f97-a80b-b25a21db-86fa-cb4c3d323f7b"
#       ],
#       "id":"4114-582a-d58bb27c-a0cf-e417643e9b7d",
#       "modified":"2025-05-14T18:36:09Z",
#       "name":"TM3_SIFMAIndex2025-05-14T14:35:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-10T18:46:56Z",
#       "availableTo":"2025-12-10T18:46:56Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-10T18:40:00Z",
#       "contentTo":"2025-06-10T18:45:00Z",
#       "created":"2025-06-10T18:46:56Z",
#       "files":[
#         "46ea-7dcb-a219691a-afb4-e318906a1eed"
#       ],
#       "id":"4114-58ec-2d4c6229-a60c-d72861fa0a6c",
#       "modified":"2025-06-10T18:46:59Z",
#       "name":"TM3_SIFMAIndex2025-06-10T14:45:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-14T20:56:24Z",
#       "availableTo":"2025-11-14T20:56:24Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-14T20:50:00Z",
#       "contentTo":"2025-05-14T20:55:00Z",
#       "created":"2025-05-14T20:56:24Z",
#       "files":[
#         "42f4-5e59-1e079bf1-9851-fe5479f58936"
#       ],
#       "id":"4114-a2d8-2584bb5f-ac8e-e964cef3dfe6",
#       "modified":"2025-05-14T20:56:27Z",
#       "name":"TM3_SIFMAIndex2025-05-14T16:55:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-22T16:16:51Z",
#       "availableTo":"2025-10-22T16:16:51Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-22T16:10:00Z",
#       "contentTo":"2025-04-22T16:15:00Z",
#       "created":"2025-04-22T16:16:51Z",
#       "files":[
#         "4c0c-78d9-11e6a75a-b40a-739a684d7fd9"
#       ],
#       "id":"4117-1f4a-c9cf2bd3-9b4f-83039d477d90",
#       "modified":"2025-04-22T16:16:52Z",
#       "name":"TM3_SIFMAIndex2025-04-22T12:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-17T19:20:48Z",
#       "availableTo":"2025-10-17T19:20:48Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-17T19:15:00Z",
#       "contentTo":"2025-04-17T19:20:00Z",
#       "created":"2025-04-17T19:20:48Z",
#       "files":[
#         "4cbf-4212-e50c19ed-b9b3-74b8f39e9939"
#       ],
#       "id":"411a-c433-58ae1667-a31d-077b25e4a4a2",
#       "modified":"2025-04-17T19:20:50Z",
#       "name":"TM3_SIFMAIndex2025-04-17T15:20:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-20T20:51:23Z",
#       "availableTo":"2025-11-20T20:51:22Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-20T20:45:00Z",
#       "contentTo":"2025-05-20T20:50:00Z",
#       "created":"2025-05-20T20:51:23Z",
#       "files":[
#         "43f9-33e6-d42f5096-89ba-f65e20ca5ccf"
#       ],
#       "id":"411e-9845-cff70b27-8e99-a5c9b0643ddd",
#       "modified":"2025-05-20T20:51:25Z",
#       "name":"TM3_SIFMAIndex2025-05-20T16:50:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-15T16:21:26Z",
#       "availableTo":"2025-11-15T16:21:26Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-15T16:15:00Z",
#       "contentTo":"2025-05-15T16:20:00Z",
#       "created":"2025-05-15T16:21:26Z",
#       "files":[
#         "4ee8-89cf-88097959-b30c-37de91f7c9d4"
#       ],
#       "id":"411f-6855-ca1fe126-ae91-089f34f0cb5d",
#       "modified":"2025-05-15T16:21:29Z",
#       "name":"TM3_SIFMAIndex2025-05-15T12:20:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-18T18:26:28Z",
#       "availableTo":"2025-12-18T18:26:28Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-18T18:20:00Z",
#       "contentTo":"2025-06-18T18:25:00Z",
#       "created":"2025-06-18T18:26:28Z",
#       "files":[
#         "4cc3-d4a0-607deea9-8594-0fb3961d48f1"
#       ],
#       "id":"4120-6011-41b2aaef-bd0e-d79add725938",
#       "modified":"2025-06-18T18:26:31Z",
#       "name":"TM3_SIFMAIndex2025-06-18T14:25:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-08T17:58:15Z",
#       "availableTo":"2025-11-08T17:58:15Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-08T17:50:00Z",
#       "contentTo":"2025-05-08T17:55:00Z",
#       "created":"2025-05-08T17:58:15Z",
#       "files":[
#         "4e2f-5ba2-31398d11-acca-c534b180bf9f"
#       ],
#       "id":"4126-c585-71b45873-9e7a-87ad9ebdeebc",
#       "modified":"2025-05-08T17:58:18Z",
#       "name":"TM3_SIFMAIndex2025-05-08T13:55:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-22T16:16:31Z",
#       "availableTo":"2025-11-22T16:16:31Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-22T16:10:00Z",
#       "contentTo":"2025-05-22T16:15:00Z",
#       "created":"2025-05-22T16:16:31Z",
#       "files":[
#         "415d-00ec-11c71abc-8874-eea3444e412d"
#       ],
#       "id":"4128-5026-3abce01e-9963-d5b34f496d53",
#       "modified":"2025-05-22T16:16:34Z",
#       "name":"TM3_SIFMAIndex2025-05-22T12:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-14T18:41:38Z",
#       "availableTo":"2025-11-14T18:41:38Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-14T18:35:00Z",
#       "contentTo":"2025-05-14T18:40:00Z",
#       "created":"2025-05-14T18:41:38Z",
#       "files":[
#         "4d4f-f0e9-30e204b4-b894-7adc7d2ff55c"
#       ],
#       "id":"4128-f15b-b60632c0-8036-86613de86dbe",
#       "modified":"2025-05-14T18:41:41Z",
#       "name":"TM3_SIFMAIndex2025-05-14T14:40:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-01T17:46:10Z",
#       "availableTo":"2025-11-01T17:46:10Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-01T17:40:00Z",
#       "contentTo":"2025-05-01T17:45:00Z",
#       "created":"2025-05-01T17:46:10Z",
#       "files":[
#         "48b3-1478-78902ae9-bffd-4699ce78df5a"
#       ],
#       "id":"412b-774e-e3adf52e-b9d2-27381c9885d8",
#       "modified":"2025-05-01T17:46:13Z",
#       "name":"TM3_SIFMAIndex2025-05-01T13:45:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-04T20:20:46Z",
#       "availableTo":"2025-12-04T20:20:46Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-04T20:15:00Z",
#       "contentTo":"2025-06-04T20:20:00Z",
#       "created":"2025-06-04T20:20:46Z",
#       "files":[
#         "42b9-2380-bcdac911-8c3f-23bc935fd49a"
#       ],
#       "id":"412c-7636-f83754e1-8b95-30c9cf0bf33f",
#       "modified":"2025-06-04T20:20:49Z",
#       "name":"TM3_SIFMAIndex2025-06-04T16:20:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-18T16:08:02Z",
#       "availableTo":"2025-12-18T16:08:02Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-18T16:00:00Z",
#       "contentTo":"2025-06-18T16:05:00Z",
#       "created":"2025-06-18T16:08:02Z",
#       "files":[
#         "4b2a-7b71-b4a5bff0-abe9-62f1bcde8791"
#       ],
#       "id":"4131-cdbe-7ece044a-aaf7-721b17d4e76c",
#       "modified":"2025-06-18T16:08:05Z",
#       "name":"TM3_SIFMAIndex2025-06-18T12:05:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-17T19:16:50Z",
#       "availableTo":"2025-12-17T19:16:50Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-17T19:10:00Z",
#       "contentTo":"2025-06-17T19:15:00Z",
#       "created":"2025-06-17T19:16:50Z",
#       "files":[
#         "4848-3b7f-b85c8c83-b010-a6c0f6b23d8a"
#       ],
#       "id":"4132-56a0-27a415bf-98e8-e990aa36ecfe",
#       "modified":"2025-06-17T19:16:53Z",
#       "name":"TM3_SIFMAIndex2025-06-17T15:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-20T16:16:35Z",
#       "availableTo":"2025-11-20T16:16:35Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-20T16:10:00Z",
#       "contentTo":"2025-05-20T16:15:00Z",
#       "created":"2025-05-20T16:16:35Z",
#       "files":[
#         "4035-27b3-49082fb7-be9c-7684251aa7f6"
#       ],
#       "id":"4135-4822-660d6656-8e3c-b757a7645c94",
#       "modified":"2025-05-20T16:16:38Z",
#       "name":"TM3_SIFMAIndex2025-05-20T12:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-17T17:11:22Z",
#       "availableTo":"2025-10-17T17:11:22Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-17T17:05:00Z",
#       "contentTo":"2025-04-17T17:10:00Z",
#       "created":"2025-04-17T17:11:22Z",
#       "files":[
#         "4c10-126d-5b2ea8f8-81b4-96c984402650"
#       ],
#       "id":"4138-9117-e8bba9c0-bb6e-d3307d6e9f56",
#       "modified":"2025-04-17T17:11:24Z",
#       "name":"TM3_SIFMAIndex2025-04-17T13:10:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-20T18:21:17Z",
#       "availableTo":"2025-11-20T18:21:17Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-20T18:15:00Z",
#       "contentTo":"2025-05-20T18:20:00Z",
#       "created":"2025-05-20T18:21:17Z",
#       "files":[
#         "40bc-38df-48c38eb5-a3d9-24c1052be3c8"
#       ],
#       "id":"4139-d557-faed024f-87e4-7eab527eb03d",
#       "modified":"2025-05-20T18:21:20Z",
#       "name":"TM3_SIFMAIndex2025-05-20T14:20:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-05T16:56:30Z",
#       "availableTo":"2025-12-05T16:56:30Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-05T16:50:00Z",
#       "contentTo":"2025-06-05T16:55:00Z",
#       "created":"2025-06-05T16:56:30Z",
#       "files":[
#         "49a8-e64c-9b0e91df-a741-071425c2431e"
#       ],
#       "id":"413a-2a9c-9b0f2937-af6e-cc5aa7582972",
#       "modified":"2025-06-05T16:56:32Z",
#       "name":"TM3_SIFMAIndex2025-06-05T12:55:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-14T17:36:10Z",
#       "availableTo":"2025-11-14T17:36:10Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-14T17:30:00Z",
#       "contentTo":"2025-05-14T17:35:00Z",
#       "created":"2025-05-14T17:36:10Z",
#       "files":[
#         "40aa-ed5a-7e002622-bc5f-d88c2d240758"
#       ],
#       "id":"413b-a31f-1f572be5-97af-1410989151ae",
#       "modified":"2025-05-14T17:36:13Z",
#       "name":"TM3_SIFMAIndex2025-05-14T13:35:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-22T17:16:33Z",
#       "availableTo":"2025-11-22T17:16:33Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-22T17:10:00Z",
#       "contentTo":"2025-05-22T17:15:00Z",
#       "created":"2025-05-22T17:16:33Z",
#       "files":[
#         "48ad-81a1-e3a55910-9908-cfa8104783e0"
#       ],
#       "id":"4143-8aed-b0a6e65b-a21a-bc5ee7a57e4d",
#       "modified":"2025-05-22T17:16:36Z",
#       "name":"TM3_SIFMAIndex2025-05-22T13:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-23T20:06:31Z",
#       "availableTo":"2025-10-23T20:06:30Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-23T20:00:00Z",
#       "contentTo":"2025-04-23T20:05:00Z",
#       "created":"2025-04-23T20:06:31Z",
#       "files":[
#         "4a14-040b-bb6a9398-aecb-ddafc4c852c7"
#       ],
#       "id":"4145-6b3c-0ed81811-b0b1-621a9b5f6ce1",
#       "modified":"2025-04-23T20:06:32Z",
#       "name":"TM3_SIFMAIndex2025-04-23T16:05:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-28T16:16:41Z",
#       "availableTo":"2025-11-28T16:16:41Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-28T16:10:00Z",
#       "contentTo":"2025-05-28T16:15:00Z",
#       "created":"2025-05-28T16:16:41Z",
#       "files":[
#         "4ad7-75d0-27399663-a5be-60e31ae624fd"
#       ],
#       "id":"4146-ee0d-66eb0ea0-8998-d4be093c27ba",
#       "modified":"2025-05-28T16:16:44Z",
#       "name":"TM3_SIFMAIndex2025-05-28T12:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-11T17:35:46Z",
#       "availableTo":"2025-12-11T17:35:46Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-11T17:30:00Z",
#       "contentTo":"2025-06-11T17:35:00Z",
#       "created":"2025-06-11T17:35:46Z",
#       "files":[
#         "4546-4754-278b6d64-93b7-1d031be4735b"
#       ],
#       "id":"4148-c424-009f0333-811d-52c009071479",
#       "modified":"2025-06-11T17:35:49Z",
#       "name":"TM3_SIFMAIndex2025-06-11T13:35:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-28T16:41:36Z",
#       "availableTo":"2025-11-28T16:41:36Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-28T16:35:00Z",
#       "contentTo":"2025-05-28T16:40:00Z",
#       "created":"2025-05-28T16:41:36Z",
#       "files":[
#         "4ee1-022a-7d3a39a8-8cf8-42bd5968e2ed"
#       ],
#       "id":"4149-d389-58f0dee7-b607-05bcaec25da9",
#       "modified":"2025-05-28T16:41:39Z",
#       "name":"TM3_SIFMAIndex2025-05-28T12:40:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-22T19:11:03Z",
#       "availableTo":"2025-10-22T19:11:03Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-22T19:05:00Z",
#       "contentTo":"2025-04-22T19:10:00Z",
#       "created":"2025-04-22T19:11:03Z",
#       "files":[
#         "422c-100d-2dbe57ee-a3c5-57f0e2760cd5"
#       ],
#       "id":"414c-f732-a03631fe-a92e-0613766ac214",
#       "modified":"2025-04-22T19:11:04Z",
#       "name":"TM3_SIFMAIndex2025-04-22T15:10:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-08T17:42:38Z",
#       "availableTo":"2025-11-08T17:42:38Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-08T17:35:00Z",
#       "contentTo":"2025-05-08T17:40:00Z",
#       "created":"2025-05-08T17:42:38Z",
#       "files":[
#         "480f-97a2-06c20d37-8f72-c796cfc48017"
#       ],
#       "id":"414e-5640-e79498a4-b818-e136801e8a96",
#       "modified":"2025-05-08T17:42:41Z",
#       "name":"TM3_SIFMAIndex2025-05-08T13:40:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-12T17:06:12Z",
#       "availableTo":"2025-12-12T17:06:12Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-12T17:00:00Z",
#       "contentTo":"2025-06-12T17:05:00Z",
#       "created":"2025-06-12T17:06:12Z",
#       "files":[
#         "4ab7-9a32-c7e45080-8b6b-60054eb19b30"
#       ],
#       "id":"414f-35b5-050b8d96-9478-ec50eba57b7f",
#       "modified":"2025-06-12T17:06:15Z",
#       "name":"TM3_SIFMAIndex2025-06-12T13:05:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-14T18:21:10Z",
#       "availableTo":"2025-11-14T18:21:09Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-14T18:15:00Z",
#       "contentTo":"2025-05-14T18:20:00Z",
#       "created":"2025-05-14T18:21:10Z",
#       "files":[
#         "4993-9713-933af76e-bd9d-6085376c62fc"
#       ],
#       "id":"4150-f860-ca5244ff-821d-08c4fda0a1c7",
#       "modified":"2025-05-14T18:21:13Z",
#       "name":"TM3_SIFMAIndex2025-05-14T14:20:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-24T16:11:22Z",
#       "availableTo":"2025-12-24T16:11:22Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-24T16:05:00Z",
#       "contentTo":"2025-06-24T16:10:00Z",
#       "created":"2025-06-24T16:11:22Z",
#       "files":[
#         "465c-f120-41306222-91c9-a6deb19e800d"
#       ],
#       "id":"4153-7f86-ce3f2cf0-af45-3c9b60258647",
#       "modified":"2025-06-24T16:11:24Z",
#       "name":"TM3_SIFMAIndex2025-06-24T12:10:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-08T16:58:34Z",
#       "availableTo":"2025-11-08T16:58:33Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-08T16:50:00Z",
#       "contentTo":"2025-05-08T16:55:00Z",
#       "created":"2025-05-08T16:58:34Z",
#       "files":[
#         "420e-a00b-eb768b21-93f9-df3a411bff00"
#       ],
#       "id":"415c-4f5e-14808450-985e-68621cb1bef8",
#       "modified":"2025-05-08T16:58:36Z",
#       "name":"TM3_SIFMAIndex2025-05-08T12:55:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-15T19:36:01Z",
#       "availableTo":"2025-11-15T19:36:01Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-15T19:30:00Z",
#       "contentTo":"2025-05-15T19:35:00Z",
#       "created":"2025-05-15T19:36:01Z",
#       "files":[
#         "49e8-5c2e-cc75dc1d-80bc-60e22199c417"
#       ],
#       "id":"415e-ff15-529ebe4b-9981-64a809b1c697",
#       "modified":"2025-05-15T19:36:04Z",
#       "name":"TM3_SIFMAIndex2025-05-15T15:35:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-17T18:16:39Z",
#       "availableTo":"2025-10-17T18:16:39Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-17T18:10:00Z",
#       "contentTo":"2025-04-17T18:15:00Z",
#       "created":"2025-04-17T18:16:39Z",
#       "files":[
#         "4ebf-9cbd-32462371-9f82-2f9b35a49470"
#       ],
#       "id":"4160-8d7c-a26300f6-ac78-6076dc24364c",
#       "modified":"2025-04-17T18:16:41Z",
#       "name":"TM3_SIFMAIndex2025-04-17T14:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-06T17:37:33Z",
#       "availableTo":"2025-11-06T17:37:33Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-06T17:30:00Z",
#       "contentTo":"2025-05-06T17:35:00Z",
#       "created":"2025-05-06T17:37:33Z",
#       "files":[
#         "4ab3-e5e9-260ea5a9-954d-94804a803366"
#       ],
#       "id":"4160-c3b2-4aab5bd2-8b45-b4259f343efa",
#       "modified":"2025-05-06T17:37:36Z",
#       "name":"TM3_SIFMAIndex2025-05-06T13:35:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-24T17:35:47Z",
#       "availableTo":"2025-12-24T17:35:47Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-24T17:30:00Z",
#       "contentTo":"2025-06-24T17:35:00Z",
#       "created":"2025-06-24T17:35:47Z",
#       "files":[
#         "4b5e-e55d-886df891-b5b7-f5e105f1fe25"
#       ],
#       "id":"4162-e292-9ae43368-9a04-b83525195e54",
#       "modified":"2025-06-24T17:35:50Z",
#       "name":"TM3_SIFMAIndex2025-06-24T13:35:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-23T18:16:12Z",
#       "availableTo":"2025-10-23T18:16:12Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-23T18:10:00Z",
#       "contentTo":"2025-04-23T18:15:00Z",
#       "created":"2025-04-23T18:16:12Z",
#       "files":[
#         "4073-92de-4b21ab44-9b7b-dabf08f1462c"
#       ],
#       "id":"416e-fdb3-ca444cfc-b913-4e5f62e36c16",
#       "modified":"2025-04-23T18:16:13Z",
#       "name":"TM3_SIFMAIndex2025-04-23T14:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-10T17:21:11Z",
#       "availableTo":"2025-12-10T17:21:11Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-10T17:15:00Z",
#       "contentTo":"2025-06-10T17:20:00Z",
#       "created":"2025-06-10T17:21:11Z",
#       "files":[
#         "4d60-2cfc-1d954073-a203-1f1c404df379"
#       ],
#       "id":"416f-f972-dc3418c5-a9ec-895be8ba1239",
#       "modified":"2025-06-10T17:21:14Z",
#       "name":"TM3_SIFMAIndex2025-06-10T13:20:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-11T16:42:04Z",
#       "availableTo":"2025-12-11T16:42:04Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-11T16:35:00Z",
#       "contentTo":"2025-06-11T16:40:00Z",
#       "created":"2025-06-11T16:42:04Z",
#       "files":[
#         "4455-e9de-8b709558-b9b9-b95649a8b083"
#       ],
#       "id":"4173-4cf9-0ea06e36-baaa-1bd904df0a09",
#       "modified":"2025-06-11T16:42:07Z",
#       "name":"TM3_SIFMAIndex2025-06-11T12:40:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-29T18:21:11Z",
#       "availableTo":"2025-10-29T18:21:11Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-29T18:15:00Z",
#       "contentTo":"2025-04-29T18:20:00Z",
#       "created":"2025-04-29T18:21:11Z",
#       "files":[
#         "4085-2475-b731fa8b-99b1-4f061edbff2b"
#       ],
#       "id":"4176-30d8-41ed2b70-b705-f2f1e3ff2e6f",
#       "modified":"2025-04-29T18:21:14Z",
#       "name":"TM3_SIFMAIndex2025-04-29T14:20:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-17T18:30:51Z",
#       "availableTo":"2025-10-17T18:30:51Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-17T18:25:00Z",
#       "contentTo":"2025-04-17T18:30:00Z",
#       "created":"2025-04-17T18:30:51Z",
#       "files":[
#         "4524-3e97-1c476285-8ea2-2fba0c77f86e"
#       ],
#       "id":"4177-a617-1d26be99-9c1c-31341471b62d",
#       "modified":"2025-04-17T18:30:52Z",
#       "name":"TM3_SIFMAIndex2025-04-17T14:30:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-25T17:02:06Z",
#       "availableTo":"2025-12-25T17:02:06Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-25T16:55:00Z",
#       "contentTo":"2025-06-25T17:00:00Z",
#       "created":"2025-06-25T17:02:06Z",
#       "files":[
#         "4f07-4439-4576b8ac-a694-5bb522ddaf46"
#       ],
#       "id":"4178-e4cd-50cb01f1-aa80-731ba84fe3cd",
#       "modified":"2025-06-25T17:02:09Z",
#       "name":"TM3_SIFMAIndex2025-06-25T13:00:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-22T17:41:52Z",
#       "availableTo":"2025-10-22T17:41:52Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-22T17:35:00Z",
#       "contentTo":"2025-04-22T17:40:00Z",
#       "created":"2025-04-22T17:41:52Z",
#       "files":[
#         "43ae-c23c-46b56236-8a51-4f3b975a157b"
#       ],
#       "id":"4179-dbc8-8b374a92-896e-cdc4f757a4a8",
#       "modified":"2025-04-22T17:41:53Z",
#       "name":"TM3_SIFMAIndex2025-04-22T13:40:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-27T16:46:35Z",
#       "availableTo":"2025-11-27T16:46:35Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-27T16:40:00Z",
#       "contentTo":"2025-05-27T16:45:00Z",
#       "created":"2025-05-27T16:46:35Z",
#       "files":[
#         "4e9e-524b-a48c99ac-a793-6b807eb1caf6"
#       ],
#       "id":"417f-f58b-78380fa9-8cf9-5ca74734633c",
#       "modified":"2025-05-27T16:46:38Z",
#       "name":"TM3_SIFMAIndex2025-05-27T12:45:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-18T17:35:53Z",
#       "availableTo":"2025-12-18T17:35:53Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-18T17:30:00Z",
#       "contentTo":"2025-06-18T17:35:00Z",
#       "created":"2025-06-18T17:35:53Z",
#       "files":[
#         "4dee-afb7-6be5d851-8a12-1fa45cabef13"
#       ],
#       "id":"4180-3207-c6208afb-bc74-ac53729695dd",
#       "modified":"2025-06-18T17:35:56Z",
#       "name":"TM3_SIFMAIndex2025-06-18T13:35:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-08T20:06:23Z",
#       "availableTo":"2025-11-08T20:06:23Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-08T20:00:00Z",
#       "contentTo":"2025-05-08T20:05:00Z",
#       "created":"2025-05-08T20:06:23Z",
#       "files":[
#         "4a77-3b6e-c631c440-904b-c5c8adc3012b"
#       ],
#       "id":"418c-8d89-8d443c8b-a1ae-9db45dae03f6",
#       "modified":"2025-05-08T20:06:26Z",
#       "name":"TM3_SIFMAIndex2025-05-08T16:05:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-18T19:16:33Z",
#       "availableTo":"2025-12-18T19:16:33Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-18T19:10:00Z",
#       "contentTo":"2025-06-18T19:15:00Z",
#       "created":"2025-06-18T19:16:33Z",
#       "files":[
#         "4685-9c5c-83222cdf-995e-4730c9e2cb4e"
#       ],
#       "id":"418d-5523-d75e20bb-a3cb-c9593c98e466",
#       "modified":"2025-06-18T19:16:36Z",
#       "name":"TM3_SIFMAIndex2025-06-18T15:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-04T20:06:17Z",
#       "availableTo":"2025-12-04T20:06:17Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-04T20:00:00Z",
#       "contentTo":"2025-06-04T20:05:00Z",
#       "created":"2025-06-04T20:06:17Z",
#       "files":[
#         "46b9-5b5e-9e65304a-93e7-4f2c0de22f3e"
#       ],
#       "id":"418e-5cff-3f1ae8ef-8fcd-2e59cf43464b",
#       "modified":"2025-06-04T20:06:20Z",
#       "name":"TM3_SIFMAIndex2025-06-04T16:05:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-12T20:46:49Z",
#       "availableTo":"2025-12-12T20:46:49Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-12T20:40:00Z",
#       "contentTo":"2025-06-12T20:45:00Z",
#       "created":"2025-06-12T20:46:49Z",
#       "files":[
#         "4e89-1382-06e02329-89c3-2e31d9db7549"
#       ],
#       "id":"418e-5fed-0ae879b0-8949-dd0e8dc7a1b1",
#       "modified":"2025-06-12T20:46:52Z",
#       "name":"TM3_SIFMAIndex2025-06-12T16:45:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-18T18:56:29Z",
#       "availableTo":"2025-12-18T18:56:29Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-18T18:50:00Z",
#       "contentTo":"2025-06-18T18:55:00Z",
#       "created":"2025-06-18T18:56:29Z",
#       "files":[
#         "4d9d-6a21-284de842-9a38-f2ef32f59970"
#       ],
#       "id":"418e-85c9-40eee64d-8d46-90cb51b10027",
#       "modified":"2025-06-18T18:56:31Z",
#       "name":"TM3_SIFMAIndex2025-06-18T14:55:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-29T20:20:49Z",
#       "availableTo":"2025-11-29T20:20:48Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-29T20:15:00Z",
#       "contentTo":"2025-05-29T20:20:00Z",
#       "created":"2025-05-29T20:20:49Z",
#       "files":[
#         "4961-54ee-2047b0b4-a7fc-ce1be097d1b2"
#       ],
#       "id":"418f-72e8-39e931be-8ace-968ef82a6a0a",
#       "modified":"2025-05-29T20:20:51Z",
#       "name":"TM3_SIFMAIndex2025-05-29T16:20:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-28T18:46:29Z",
#       "availableTo":"2025-11-28T18:46:28Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-28T18:40:00Z",
#       "contentTo":"2025-05-28T18:45:00Z",
#       "created":"2025-05-28T18:46:29Z",
#       "files":[
#         "4975-14d5-06fb557d-bfc7-55725e2d3f24"
#       ],
#       "id":"418f-8500-14eaa819-b3ad-beba09e8ee20",
#       "modified":"2025-05-28T18:46:31Z",
#       "name":"TM3_SIFMAIndex2025-05-28T14:45:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-29T16:06:49Z",
#       "availableTo":"2025-11-29T16:06:49Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-29T16:00:00Z",
#       "contentTo":"2025-05-29T16:05:00Z",
#       "created":"2025-05-29T16:06:49Z",
#       "files":[
#         "4d21-ce62-f04d93e6-89f9-6ccedfe00479"
#       ],
#       "id":"4193-8202-4052a72b-914d-4e5c859a2988",
#       "modified":"2025-05-29T16:06:52Z",
#       "name":"TM3_SIFMAIndex2025-05-29T12:05:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-17T17:35:49Z",
#       "availableTo":"2025-12-17T17:35:49Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-17T17:30:00Z",
#       "contentTo":"2025-06-17T17:35:00Z",
#       "created":"2025-06-17T17:35:49Z",
#       "files":[
#         "4197-f43e-9d930f25-ac4f-e1486b6c6f12"
#       ],
#       "id":"4193-8d85-bd98885e-b278-1f3ba2d72ba0",
#       "modified":"2025-06-17T17:35:52Z",
#       "name":"TM3_SIFMAIndex2025-06-17T13:35:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-24T19:25:59Z",
#       "availableTo":"2025-12-24T19:25:58Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-24T19:20:00Z",
#       "contentTo":"2025-06-24T19:25:00Z",
#       "created":"2025-06-24T19:25:59Z",
#       "files":[
#         "49fa-a4aa-f2ee958f-b5c4-0c5bd9447819"
#       ],
#       "id":"4195-a771-e4abf52c-88e9-8933ded0008d",
#       "modified":"2025-06-24T19:26:01Z",
#       "name":"TM3_SIFMAIndex2025-06-24T15:25:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-15T16:36:00Z",
#       "availableTo":"2025-11-15T16:36:00Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-15T16:30:00Z",
#       "contentTo":"2025-05-15T16:35:00Z",
#       "created":"2025-05-15T16:36:00Z",
#       "files":[
#         "44dd-d5ac-073baa3b-81c6-4fc98c5fa1f6"
#       ],
#       "id":"4197-115b-76d15867-b447-335f1660576b",
#       "modified":"2025-05-15T16:36:03Z",
#       "name":"TM3_SIFMAIndex2025-05-15T12:35:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-05T19:01:52Z",
#       "availableTo":"2025-12-05T19:01:52Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-05T18:55:00Z",
#       "contentTo":"2025-06-05T19:00:00Z",
#       "created":"2025-06-05T19:01:52Z",
#       "files":[
#         "46d8-24ee-1220026d-b3fd-0adc6eca81ff"
#       ],
#       "id":"4197-e90c-aa430625-9794-bccef2066e49",
#       "modified":"2025-06-05T19:01:54Z",
#       "name":"TM3_SIFMAIndex2025-06-05T15:00:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-22T18:01:33Z",
#       "availableTo":"2025-11-22T18:01:33Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-22T17:55:00Z",
#       "contentTo":"2025-05-22T18:00:00Z",
#       "created":"2025-05-22T18:01:33Z",
#       "files":[
#         "4c4e-ac5f-f08d2277-91c5-55692ea5ecc6"
#       ],
#       "id":"4199-b16a-c73e7b5a-a6e8-075ca3896719",
#       "modified":"2025-05-22T18:01:36Z",
#       "name":"TM3_SIFMAIndex2025-05-22T14:00:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-21T16:51:40Z",
#       "availableTo":"2025-11-21T16:51:40Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-21T16:45:00Z",
#       "contentTo":"2025-05-21T16:50:00Z",
#       "created":"2025-05-21T16:51:40Z",
#       "files":[
#         "4bec-47df-e0b98895-88ec-7bcf43f7e03e"
#       ],
#       "id":"419b-e3f0-349124d2-9a9c-a67d475d2274",
#       "modified":"2025-05-21T16:51:43Z",
#       "name":"TM3_SIFMAIndex2025-05-21T12:50:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-28T18:16:15Z",
#       "availableTo":"2025-11-28T18:16:15Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-28T18:10:00Z",
#       "contentTo":"2025-05-28T18:15:00Z",
#       "created":"2025-05-28T18:16:15Z",
#       "files":[
#         "4cb9-ce88-b75d8f87-8395-f2012434563a"
#       ],
#       "id":"41a2-9497-4719a510-86f3-18ac19028982",
#       "modified":"2025-05-28T18:16:18Z",
#       "name":"TM3_SIFMAIndex2025-05-28T14:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-28T18:42:16Z",
#       "availableTo":"2025-11-28T18:42:16Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-28T18:35:00Z",
#       "contentTo":"2025-05-28T18:40:00Z",
#       "created":"2025-05-28T18:42:16Z",
#       "files":[
#         "4ba2-4657-3ed651e7-8bcb-fabff7511b6a"
#       ],
#       "id":"41a3-c29b-224a3698-ad07-08ba111576a3",
#       "modified":"2025-05-28T18:42:19Z",
#       "name":"TM3_SIFMAIndex2025-05-28T14:40:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-10T17:26:05Z",
#       "availableTo":"2025-12-10T17:26:04Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-10T17:20:00Z",
#       "contentTo":"2025-06-10T17:25:00Z",
#       "created":"2025-06-10T17:26:05Z",
#       "files":[
#         "4413-e4f6-311073c7-98c2-ef2c77c7b075"
#       ],
#       "id":"41a4-9a01-1de7dcf4-9806-a4ed3287ba70",
#       "modified":"2025-06-10T17:26:08Z",
#       "name":"TM3_SIFMAIndex2025-06-10T13:25:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-17T16:21:03Z",
#       "availableTo":"2025-12-17T16:21:03Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-17T16:15:00Z",
#       "contentTo":"2025-06-17T16:20:00Z",
#       "created":"2025-06-17T16:21:03Z",
#       "files":[
#         "427a-d9b8-7cf3fdb1-a19f-b46824935e74"
#       ],
#       "id":"41a5-6651-860459c1-89dc-1555217efc99",
#       "modified":"2025-06-17T16:21:06Z",
#       "name":"TM3_SIFMAIndex2025-06-17T12:20:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-17T16:51:11Z",
#       "availableTo":"2025-12-17T16:51:11Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-17T16:45:00Z",
#       "contentTo":"2025-06-17T16:50:00Z",
#       "created":"2025-06-17T16:51:11Z",
#       "files":[
#         "4b6c-dd83-fafad27d-839c-5800fe92e235"
#       ],
#       "id":"41a7-af71-abc19362-aaf9-be11594ff16d",
#       "modified":"2025-06-17T16:51:15Z",
#       "name":"TM3_SIFMAIndex2025-06-17T12:50:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-22T16:51:48Z",
#       "availableTo":"2025-10-22T16:51:48Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-22T16:45:00Z",
#       "contentTo":"2025-04-22T16:50:00Z",
#       "created":"2025-04-22T16:51:48Z",
#       "files":[
#         "4c07-89cf-9fbeb498-92a7-89351bea2588"
#       ],
#       "id":"41aa-22e0-00cb25f8-ab65-dab128472d34",
#       "modified":"2025-04-22T16:51:50Z",
#       "name":"TM3_SIFMAIndex2025-04-22T12:50:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-19T18:51:31Z",
#       "availableTo":"2025-12-19T18:51:31Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-19T18:45:00Z",
#       "contentTo":"2025-06-19T18:50:00Z",
#       "created":"2025-06-19T18:51:31Z",
#       "files":[
#         "456d-e389-6effb513-885c-da9ded2d06ce"
#       ],
#       "id":"41ac-4e51-f89540c5-b924-c12867868db3",
#       "modified":"2025-06-19T18:51:34Z",
#       "name":"TM3_SIFMAIndex2025-06-19T14:50:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-29T18:01:52Z",
#       "availableTo":"2025-11-29T18:01:52Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-29T17:55:00Z",
#       "contentTo":"2025-05-29T18:00:00Z",
#       "created":"2025-05-29T18:01:52Z",
#       "files":[
#         "4882-8a21-68bb4246-bbb2-fe718ee66551"
#       ],
#       "id":"41ac-dd4f-667cb3ce-95cf-c006ea6a1960",
#       "modified":"2025-05-29T18:01:55Z",
#       "name":"TM3_SIFMAIndex2025-05-29T14:00:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-30T20:16:40Z",
#       "availableTo":"2025-10-30T20:16:40Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-30T20:10:00Z",
#       "contentTo":"2025-04-30T20:15:00Z",
#       "created":"2025-04-30T20:16:40Z",
#       "files":[
#         "46d0-e53b-cbe46a40-bbef-eda30bfbdffd"
#       ],
#       "id":"41ad-2a6f-3eab99ff-b3f4-a69a09b8f271",
#       "modified":"2025-04-30T20:16:43Z",
#       "name":"TM3_SIFMAIndex2025-04-30T16:15:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-28T20:06:14Z",
#       "availableTo":"2025-11-28T20:06:13Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-28T20:00:00Z",
#       "contentTo":"2025-05-28T20:05:00Z",
#       "created":"2025-05-28T20:06:14Z",
#       "files":[
#         "441d-6251-6486c84a-bc47-c5508ecfe70e"
#       ],
#       "id":"41ad-925a-f170f9c5-a00d-c2e20eec86d3",
#       "modified":"2025-05-28T20:06:17Z",
#       "name":"TM3_SIFMAIndex2025-05-28T16:05:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-15T17:01:17Z",
#       "availableTo":"2025-11-15T17:01:17Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-15T16:55:00Z",
#       "contentTo":"2025-05-15T17:00:00Z",
#       "created":"2025-05-15T17:01:17Z",
#       "files":[
#         "4057-caa8-df548985-aa75-58e7cbcc03cf"
#       ],
#       "id":"41ad-c705-13a5555c-b97b-e6e7a96498ea",
#       "modified":"2025-05-15T17:01:20Z",
#       "name":"TM3_SIFMAIndex2025-05-15T13:00:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-18T18:41:26Z",
#       "availableTo":"2025-12-18T18:41:25Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-18T18:35:00Z",
#       "contentTo":"2025-06-18T18:40:00Z",
#       "created":"2025-06-18T18:41:26Z",
#       "files":[
#         "4ed1-25c8-cd70f2ef-8c9b-830eba8b29e5"
#       ],
#       "id":"41ae-b201-0706c956-9c07-dd156265853b",
#       "modified":"2025-06-18T18:41:28Z",
#       "name":"TM3_SIFMAIndex2025-06-18T14:40:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-04-23T17:21:39Z",
#       "availableTo":"2025-10-23T17:21:39Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-04-23T17:15:00Z",
#       "contentTo":"2025-04-23T17:20:00Z",
#       "created":"2025-04-23T17:21:39Z",
#       "files":[
#         "4fea-f674-c062d5d1-856d-14e06e51b161"
#       ],
#       "id":"41b1-0bb7-c903480d-b724-25f660ef79b0",
#       "modified":"2025-04-23T17:21:41Z",
#       "name":"TM3_SIFMAIndex2025-04-23T13:20:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-07T20:12:06Z",
#       "availableTo":"2025-11-07T20:12:06Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-07T20:05:00Z",
#       "contentTo":"2025-05-07T20:10:00Z",
#       "created":"2025-05-07T20:12:06Z",
#       "files":[
#         "4a90-0fa4-94bb0811-8fe1-7a1aaf074874"
#       ],
#       "id":"41b5-5ffc-39d1a512-bea7-4949c0080050",
#       "modified":"2025-05-07T20:12:09Z",
#       "name":"TM3_SIFMAIndex2025-05-07T16:10:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-05-22T20:25:59Z",
#       "availableTo":"2025-11-22T20:25:59Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-05-22T20:20:00Z",
#       "contentTo":"2025-05-22T20:25:00Z",
#       "created":"2025-05-22T20:25:59Z",
#       "files":[
#         "485d-3e92-c0f8d6d7-b1de-28a0cbbd2da6"
#       ],
#       "id":"41b5-dde2-171cf646-8ac0-ba87c63d7952",
#       "modified":"2025-05-22T20:26:02Z",
#       "name":"TM3_SIFMAIndex2025-05-22T16:25:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     },
#     {
#       "attributes":[],
#       "availableFrom":"2025-06-17T17:41:20Z",
#       "availableTo":"2025-12-17T17:41:19Z",
#       "bucketName":"bulk-custom",
#       "contentFrom":"2025-06-17T17:35:00Z",
#       "contentTo":"2025-06-17T17:40:00Z",
#       "created":"2025-06-17T17:41:20Z",
#       "files":[
#         "42a4-c36a-2c08e110-ab31-3fd320551e5c"
#       ],
#       "id":"41bd-1419-6ce144cd-aacf-25b16aa109ea",
#       "modified":"2025-06-17T17:41:30Z",
#       "name":"TM3_SIFMAIndex2025-06-17T13:40:00.000-04:00",
#       "numFiles":1,
#       "packageId":"4a2f-a444-b1f4a145-b0f9-4509ed361868",
#       "status":"READY"
#     }
#   ]
# }

# %% [markdown]
# Then you can continue to send requests to URL in ```@nextLink``` node to get the next page results.

# %% [markdown]
# ### More on /file-store/v1/file-sets?bucket parameters
#
# Beside the ```bucket``` and ```packageId```queries, the ```/file-store/v1/file-sets?bucket``` endpoint supports the following optional parameters:
#
# - *name*: The name of the file-set. Only exactly matched results are returned.
# - *packageId*: Package ID
# - *status*: Filter file-set by status (Ready/Pending)
# - *availableFrom*: Return all file-sets that become visible to permissioned users after the specified Datetime.
# - *availableTo*: Return all file-sets that is no longer visible to permissioned user after the specified Datetime.
# - *contentFrom*: Filter results by the age of the content within the file-set.
# - *contentTo*: Filter results by the age of the content within the file-set.
# - *createdSince*: Return all file-sets that have a created date after the specified Datetime
# - *modifiedSince*: Return all file-sets that have a modified date after the specified Datetime.
# - *attributes*: Return a list of publisher-defined attributes of the file-sets.
# - *pageSize*: The number of file-sets that will be shown on one page. Default value is 25.
# - *skipToken*: A token to retrieve the next set of file-set result that exceeds page size.
#
# Please find more detail on the [CFS API User Guide](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-platform-apis/documentation#cfs-api-user-guide) document.
#
#
# ### Step 3: Get the AWS S3 file URL using FileSet
#
# The next step is getting the file URL on Amazon AWS S3 service with the RDP ```/file-store/v1/files/{fileSet}/stream``` endpoint.
#
# ``` HTTP
# GET /file-store/v1/files/{fileSet}/stream?doNotRedirect=true HTTP/1.1
# Host: api.refinitiv.com
# Authorization: Bearer <Access Token>
# ```

# %%
#step 3 - get file URL from file id

FileID_url = f'{RDP_HOST}/file-store/v1/files/{file_id}/stream?doNotRedirect=true'

try:
    fileID_response = requests.get(FileID_url, headers={'Authorization': f'Bearer {access_token}'})
except requests.exceptions.RequestException as exp:
    print(f'Caught exception: {exp}')

if fileID_response.status_code == 200:  # HTTP Status 'OK'
    print('Receive File URL from RDP APIs')
else:
    print(f'RDP APIs: CFS request failure: {fileID_response.status_code} {fileID_response.reason}')
    print(f'Text: {fileID_response.text}')
# Out:
# Receive File URL from RDP APIs

# %% [markdown]
# The File URL is in the ```url``` attribute of the response message.

# %%
file_url = fileID_response.json()['url']
print(file_url)

# %% [markdown]
# ### More on /file-store/v1/files/ parameters
#
# Beside the ```file_id``` query, the ```/file-store/v1/files/``` endpoint supports the following optional parameters:
#
# - *createdSince*: Return all files that have a created date after the specified Datetime.
# - *modifiedSince*: Return all files that have a modified date after the specified Datetime.
# - *pageSize*: The number of files that will be shown on one page. Default value is 25.
# - *skipToken*: A token to retrieve the next set of file result that exceeds page size
#
# Please find more detail on the [CFS API User Guide](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-platform-apis/documentation#cfs-api-user-guide) document.

# %% [markdown]
# ### Step 4: Downloading the actual file from AWS
#
# Once you got the S3 URL. You can download the bulk file using that URL (**as is**). **Do not alter or make any changes to the URL text string**. It will cause unable to download or signature mismatch error.
#
# **Note**:
# - If you cannot download the file, please wait for a while and then retry download the file from the URL. Please do not flush the download requests.
# - The code below set ```verify = False``` property in a ```requests``` library call to workaround LSEG's beloved ZScaler blocks a download request message. **Do not** set ```verify = False``` in a Production.

# %%
#step 4 - Download file
import polling2

try:
    print(f'Downloading File from {file_url} ...')
    bulkFile_response = polling2.poll(lambda: requests.get(file_url, verify= False), 
                            step = 10,
                            poll_forever = True,
                            check_success= lambda r: r.status_code == 200)
except requests.exceptions.RequestException as exp:
    print(f'Caught exception: {exp}')

# Save the file locally.
if bulkFile_response.status_code == 200:  # HTTP Status 'OK'
    zipfilename = file_url.split("?")[0].split("/")[-1].replace("%3A","_")
    print('Download File Successfully')
    open(zipfilename, 'wb').write(bulkFile_response.content)
    print(f'{zipfilename} Saved')
else:
    print(f'RDP APIs: Request file failure: {bulkFile_response.status_code} {bulkFile_response.reason}')
    print(f'Text: {bulkFile_response.text}')

# %% [markdown]
# Now you get the CFS file that you can extract and read the file.

# %% [markdown]
# ### Step 5: Refresh Token with RDP APIs
#
# Before the session expires (based on the ```expires_in``` parameter, in seconds) , an application needs to send a Refresh Grant request message to RDP Authentication service to get a new access token before further request data from the platform.
#
# The API requires the following access credential information:
# - Refresh Token: The current Refresh Token value from the previous RDP Authentication call
# - Client ID: This is also known as ```AppKey```, and it is generated using an App key Generator. This unique identifier is defined for the user or application and is deemed confidential (not shared between users). The client_id parameter can be passed in the request body or as an “Authorization” request header that is encoded as base64.
# - Grant Type ```refresh_token```: This is for getting a new Access Token.
#
#
# ``` HTTP
# POST /auth/oauth2/v1/token HTTP/1.1
# Accept: */*
# Content-Type: application/x-www-form-urlencoded
# Host: api.refinitiv.com:443
# Content-Length: XXX
#
# refresh_token={current_refresh_token}
# &grant_type=refresh_token
# &client_id=RDP_APP_KEY
# ```
#
# **Caution: API Limit**
#
# The RDP Authentication service has the API limit described on the [RDP APIs: Limitations and Guidelines for the RDP Authentication Service](https://developers.lseg.com/en/article-catalog/article/limitations-and-guidelines-for-the-rdp-authentication-service) article.  If the application flushes the authentication request messages (both ```password``` and ```refresh_token``` grant_type) beyond the limit, the account will be blocked by the API Gateway.

# %%
#step 5 - Refreshing Token

# Send HTTP Request
auth_url = f'{RDP_HOST}/auth/oauth2/v1/token'
payload = f'grant_type=refresh_token&client_id={clientId}&refresh_token={refresh_token}'
auth_response = None

try:
    auth_response = requests.post(auth_url, 
                             headers = {'Content-Type':'application/x-www-form-urlencoded'}, 
                             data = payload, 
                             auth = (clientId, '')
                )
except requests.exceptions.RequestException as exp:
    print(f'Caught exception: {exp}')

if auth_response.status_code == 200:  # HTTP Status 'OK'
    print('Refresh Token success')
    access_token = auth_response.json()['access_token']
    refresh_token = auth_response.json()['refresh_token']
    expires_in = int(auth_response.json()['expires_in'])

if auth_response.status_code != 200:
    print(f'RDP authentication failure: {auth_response.status_code} {auth_response.reason}')
    print(f'Text: {auth_response.text}')
# Out:
# Refresh Token success

# %% [markdown]
# ### Step 6: Revoke Token to ending the session.
#
# This revocation mechanism allows an application to invalidate its tokens if the end-user logs out, changes identity, or exits the respective application. Notifying the authorization server that the token is no longer needed allows the authorization server to clean up data associated with that token (e.g., session data) and the underlying authorization grant.
#
# The API requires the following HTTP Header and Credential parameter information:
# - Header:
#     * Authorization = ```Basic <App Key+":" in Base64 format>```
#
# - Body parameter
#     * token: The current ```Access Token``` value from the previous RDP Authentication call
#
# Please be noticed
#   - The **":"** string after the **App Key**.
#   -  *the space* between the **Basic** and **App Key+":" in Base64** values.
#
#
# ``` HTTP
# POST /auth/oauth2/v1/revoke HTTP/1.1
# Accept: */*
# Content-Type: application/x-www-form-urlencoded
# Host: api.refinitiv.com:443
# Authorization: Basic <App Key+":" in Base64>
# Content-Length: XXX
#
# token={current_Access_token}
# ```

# %%
#step 7 - Revoking Token

import base64

clientId_bytes = f'{clientId}:'.encode('ascii') #please be notice ":" after clientid/appkey information.
base64_bytes = base64.b64encode(clientId_bytes)
clientId_base64 = base64_bytes.decode('ascii')

# Send HTTP Request
auth_url = f'{RDP_HOST}/auth/oauth2/v1/revoke'
payload = f'token={access_token}'
auth_response = None

try:
    auth_response = requests.post(auth_url, 
                             headers = {
                                 'Content-Type':'application/x-www-form-urlencoded',
                                 'Authorization': f'Basic {clientId_base64}'
                             }, 
                             data = payload
                )
except requests.exceptions.RequestException as exp:
    print(f'Caught exception: {exp}')

if auth_response.status_code == 200:  # HTTP Status 'OK'
    print('Revoke Token success')
if auth_response.status_code != 200:
    print(f'RDP authentication failure: {auth_response.status_code} {auth_response.reason}')
    print(f'Text: {auth_response.text}')
